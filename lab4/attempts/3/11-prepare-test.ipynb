# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (10, 5)

# %%
df = pd.read_csv('processed_data/10-concated.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275299 entries, 0 to 275298
# Data columns (total 78 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   city                                 275299 non-null  object
#  1   floor                                101526 non-null  float64
#  2   id                                   275299 non-null  object
#  3   lat                                  275299 non-null  float64
#  4   lng                                  275299 non-null  float64
#  5   osm_amenity_points_in_0.001          275299 non-null  int64
#  6   osm_amenity_points_in_0.005          275299 non-null  int64
#  7   osm_amenity_points_in_0.0075         275299 non-null  int64
#  8   osm_amenity_points_in_0.01           275299 non-null  int64
#  9   osm_building_points_in_0.001         275299 non-null  int64
#  10  osm_building_points_in_0.005         275299 non-null  int64
#  11  osm_building_points_in_0.0075        275299 non-null  int64
#  12  osm_building_points_in_0.01          275299 non-null  int64
#  13  osm_catering_points_in_0.001         275299 non-null  int64
#  14  osm_catering_points_in_0.005         275299 non-null  int64
#  15  osm_catering_points_in_0.0075        275299 non-null  int64
#  16  osm_catering_points_in_0.01          275299 non-null  int64
#  17  osm_city_closest_dist                275299 non-null  float64
#  18  osm_city_nearest_name                275299 non-null  object
#  19  osm_city_nearest_population          275245 non-null  float64
#  20  osm_crossing_closest_dist            275299 non-null  float64
#  21  osm_crossing_points_in_0.001         275299 non-null  int64
#  22  osm_crossing_points_in_0.005         275299 non-null  int64
#  23  osm_crossing_points_in_0.0075        275299 non-null  int64
#  24  osm_crossing_points_in_0.01          275299 non-null  int64
#  25  osm_culture_points_in_0.001          275299 non-null  int64
#  26  osm_culture_points_in_0.005          275299 non-null  int64
#  27  osm_culture_points_in_0.0075         275299 non-null  int64
#  28  osm_culture_points_in_0.01           275299 non-null  int64
#  29  osm_finance_points_in_0.001          275299 non-null  int64
#  30  osm_finance_points_in_0.005          275299 non-null  int64
#  31  osm_finance_points_in_0.0075         275299 non-null  int64
#  32  osm_finance_points_in_0.01           275299 non-null  int64
#  33  osm_healthcare_points_in_0.005       275299 non-null  int64
#  34  osm_healthcare_points_in_0.0075      275299 non-null  int64
#  35  osm_healthcare_points_in_0.01        275299 non-null  int64
#  36  osm_historic_points_in_0.005         275299 non-null  int64
#  37  osm_historic_points_in_0.0075        275299 non-null  int64
#  38  osm_historic_points_in_0.01          275299 non-null  int64
#  39  osm_hotels_points_in_0.005           275299 non-null  int64
#  40  osm_hotels_points_in_0.0075          275299 non-null  int64
#  41  osm_hotels_points_in_0.01            275299 non-null  int64
#  42  osm_leisure_points_in_0.005          275299 non-null  int64
#  43  osm_leisure_points_in_0.0075         275299 non-null  int64
#  44  osm_leisure_points_in_0.01           275299 non-null  int64
#  45  osm_offices_points_in_0.001          275299 non-null  int64
#  46  osm_offices_points_in_0.005          275299 non-null  int64
#  47  osm_offices_points_in_0.0075         275299 non-null  int64
#  48  osm_offices_points_in_0.01           275299 non-null  int64
#  49  osm_shops_points_in_0.001            275299 non-null  int64
#  50  osm_shops_points_in_0.005            275299 non-null  int64
#  51  osm_shops_points_in_0.0075           275299 non-null  int64
#  52  osm_shops_points_in_0.01             275299 non-null  int64
#  53  osm_subway_closest_dist              275299 non-null  float64
#  54  osm_train_stop_closest_dist          275299 non-null  float64
#  55  osm_train_stop_points_in_0.005       275299 non-null  int64
#  56  osm_train_stop_points_in_0.0075      275299 non-null  int64
#  57  osm_train_stop_points_in_0.01        275299 non-null  int64
#  58  osm_transport_stop_closest_dist      275299 non-null  float64
#  59  osm_transport_stop_points_in_0.005   275299 non-null  int64
#  60  osm_transport_stop_points_in_0.0075  275299 non-null  int64
#  61  osm_transport_stop_points_in_0.01    275299 non-null  int64
#  62  per_square_meter_price               206474 non-null  float64
#  63  reform_count_of_houses_1000          275299 non-null  int64
#  64  reform_count_of_houses_500           275299 non-null  int64
#  65  reform_house_population_1000         260758 non-null  float64
#  66  reform_house_population_500          248133 non-null  float64
#  67  reform_mean_floor_count_1000         258654 non-null  float64
#  68  reform_mean_floor_count_500          245209 non-null  float64
#  69  reform_mean_year_building_1000       259121 non-null  float64
#  70  reform_mean_year_building_500        245738 non-null  float64
#  71  region                               275299 non-null  object
#  72  total_square                         275299 non-null  float64
#  73  street                               273710 non-null  object
#  74  date                                 275299 non-null  object
#  75  realty_type                          275299 non-null  int64
#  76  pool                                 275299 non-null  object
#  77  rating_org                           68825 non-null   float64
# dtypes: float64(18), int64(53), object(7)
# memory usage: 163.8+ MB

# %%
df.describe()
# Out:
#                floor            lat            lng  \
# count  101526.000000  275299.000000  275299.000000
# mean        1.876189      54.345637      47.514960
# std         5.487294       4.254678      16.704374
# min        -3.000000      42.651897      19.892178
# 25%         1.000000      53.226353      37.583504
# 50%         1.000000      55.678864      39.681797
# 75%         1.000000      56.298480      55.927734
# max       123.000000      69.500740     151.777000
#
#        osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# count                275299.000000                275299.000000
# mean                      2.693551                    40.286416
# std                       4.182855                    52.630339
# min                       0.000000                     0.000000
# 25%                       0.000000                     7.000000
# 50%                       1.000000                    22.000000
# 75%                       4.000000                    51.000000
# max                      46.000000                   468.000000
#
#        osm_amenity_points_in_0.0075  osm_amenity_points_in_0.01  \
# count                 275299.000000               275299.000000
# mean                      80.916890                  132.196169
# std                      103.618822                  169.675198
# min                        0.000000                    0.000000
# 25%                       16.000000                   28.000000
# 50%                       46.000000                   77.000000
# 75%                      101.000000                  164.000000
# max                      850.000000                 1392.000000
#
#        osm_building_points_in_0.001  osm_building_points_in_0.005  \
# count                 275299.000000                 275299.000000
# mean                       0.037763                      0.892684
# std                        0.393757                      6.906044
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                       30.000000                    586.000000
#
#        osm_building_points_in_0.0075  ...  reform_count_of_houses_500  \
# count                  275299.000000  ...               275299.000000
# mean                        2.064385  ...                   29.844587
# std                        14.911487  ...                   27.573868
# min                         0.000000  ...                    0.000000
# 25%                         0.000000  ...                    9.000000
# 50%                         0.000000  ...                   24.000000
# 75%                         1.000000  ...                   43.000000
# max                       949.000000  ...                  289.000000
#
#        reform_house_population_1000  reform_house_population_500  \
# count                 260758.000000                248133.000000
# mean                    2031.661955                   641.860305
# std                     1355.405864                   445.144079
# min                        0.000000                     0.000000
# 25%                      916.000000                   285.000000
# 50%                     1946.000000                   599.000000
# 75%                     2972.000000                   934.000000
# max                    18392.000000                  6105.000000
#
#        reform_mean_floor_count_1000  reform_mean_floor_count_500  \
# count                 258654.000000                245209.000000
# mean                       7.066325                     7.379212
# std                        3.554087                     4.247652
# min                        0.000000                     0.000000
# 25%                        4.591837                     4.625000
# 50%                        6.386792                     6.416667
# 75%                        8.732143                     9.133333
# max                       53.717949                   221.666667
#
#        reform_mean_year_building_1000  reform_mean_year_building_500  \
# count                   259121.000000                  245738.000000
# mean                      1967.619298                    1968.080832
# std                         45.985397                      54.360950
# min                          1.000000                       1.000000
# 25%                       1960.107143                    1959.960000
# 50%                       1970.933333                    1971.714286
# 75%                       1983.800000                    1987.000000
# max                       2019.000000                    2020.000000
#
#         total_square    realty_type  rating_org
# count  275299.000000  275299.000000     68825.0
# mean      509.347246      54.927116         0.0
# std      1712.497623      47.865427         0.0
# min         5.100000      10.000000         0.0
# 25%        65.100000      10.000000         0.0
# 50%       128.000000      10.000000         0.0
# 75%       336.000000     110.000000         0.0
# max     40000.000000     110.000000         0.0
#
# [8 rows x 71 columns]

# %%
df.boxplot('floor', figsize=(15, 10))
plt.show()

# %%
df[(df.floor < 10)].floor.hist()
plt.show()

# %%
pd.options.display.max_rows = 5000
cityFrequency = df.city.value_counts(normalize=True)
print(cityFrequency)
# Out:
# Москва                                                                                             0.203070
# Санкт-Петербург                                                                                    0.067316
# Краснодар                                                                                          0.047181
# Екатеринбург                                                                                       0.030465
# Новосибирск                                                                                        0.024047
# Челябинск                                                                                          0.022361
# Самара                                                                                             0.022140
# Казань                                                                                             0.021824
# Тюмень                                                                                             0.021126
# Уфа                                                                                                0.017675
# Нижний Новгород                                                                                    0.017236
# Ростов-на-Дону                                                                                     0.016764
# Пермь                                                                                              0.013720
# Воронеж                                                                                            0.013124
# Красноярск                                                                                         0.012009
# Саратов                                                                                            0.010781
# Ставрополь                                                                                         0.009902
# Калининград                                                                                        0.009215
# Волгоград                                                                                          0.008700
# Сочи                                                                                               0.008525
# Иркутск                                                                                            0.007784
# Омск                                                                                               0.007610
# Ижевск                                                                                             0.007323
# Барнаул                                                                                            0.007214
# Киров                                                                                              0.006070
# Ярославль                                                                                          0.005656
# Ульяновск                                                                                          0.005572
# Кемерово                                                                                           0.005474
# Тольятти                                                                                           0.005369
# Белгород                                                                                           0.005180
# Пенза                                                                                              0.005042
# Тула                                                                                               0.004893
# Новороссийск                                                                                       0.004835
# Анапа                                                                                              0.004602
# Сургут                                                                                             0.004214
# Липецк                                                                                             0.004214
# Иваново                                                                                            0.004203
# Набережные Челны                                                                                   0.004054
# Балашиха                                                                                           0.003869
# Брянск                                                                                             0.003861
# Новокузнецк                                                                                        0.003658
# Томск                                                                                              0.003375
# Кострома                                                                                           0.003364
# Сыктывкар                                                                                          0.003316
# Нижний Тагил                                                                                       0.003262
# Смоленск                                                                                           0.003117
# Вологда                                                                                            0.002877
# Красногорск                                                                                        0.002779
# Химки                                                                                              0.002728
# Курск                                                                                              0.002615
# Магнитогорск                                                                                       0.002543
# Калуга                                                                                             0.002506
# Волжский                                                                                           0.002390
# Нижневартовск                                                                                      0.002129
# Таганрог                                                                                           0.002089
# Геленджик                                                                                          0.002081
# Петрозаводск                                                                                       0.002070
# Саранск                                                                                            0.001969
# Одинцово                                                                                           0.001962
# Королев                                                                                            0.001947
# Энгельс                                                                                            0.001896
# Череповец                                                                                          0.001889
# Пятигорск                                                                                          0.001820
# Подольск                                                                                           0.001787
# Люберцы                                                                                            0.001773
# Орёл                                                                                               0.001733
# Стерлитамак                                                                                        0.001642
# Дзержинск                                                                                          0.001638
# Мытищи                                                                                             0.001638
# Электросталь                                                                                       0.001537
# Мурино                                                                                             0.001507
# Видное                                                                                             0.001467
# Миасс                                                                                              0.001337
# Нефтекамск                                                                                         0.001264
# Ханты-Мансийск                                                                                     0.001228
# Старый Оскол                                                                                       0.001228
# Октябрьский                                                                                        0.001199
# Коммунарка                                                                                         0.001191
# Кисловодск                                                                                         0.001170
# Сергиев Посад                                                                                      0.001144
# Ухта                                                                                               0.001137
# Рыбинск                                                                                            0.001133
# Волгодонск                                                                                         0.001130
# Ангарск                                                                                            0.001119
# Златоуст                                                                                           0.001119
# Копейск                                                                                            0.001112
# Нижнекамск                                                                                         0.001108
# Шахты                                                                                              0.001086
# Ессентуки                                                                                          0.001086
# Обнинск                                                                                            0.001013
# Балаково                                                                                           0.001010
# Михайловск                                                                                         0.001003
# Ивантеевка                                                                                         0.001003
# Бийск                                                                                              0.000981
# Альметьевск                                                                                        0.000963
# Каменск-Уральский                                                                                  0.000959
# Реутов                                                                                             0.000959
# Коломна                                                                                            0.000952
# Жуковский                                                                                          0.000944
# Орел                                                                                               0.000937
# Батайск                                                                                            0.000897
# Звенигород                                                                                         0.000897
# Новочеркасск                                                                                       0.000897
# Раменское                                                                                          0.000875
# Бердск                                                                                             0.000872
# Ейск                                                                                               0.000872
# Димитровград                                                                                       0.000854
# Аксай                                                                                              0.000850
# Прокопьевск                                                                                        0.000839
# Новомосковск                                                                                       0.000803
# Туапсе                                                                                             0.000803
# Тобольск                                                                                           0.000803
# Братск                                                                                             0.000799
# Невинномысск                                                                                       0.000792
# Армавир                                                                                            0.000785
# Березники                                                                                          0.000777
# Майкоп                                                                                             0.000774
# Воскресенск                                                                                        0.000734
# Крымск                                                                                             0.000716
# Новокуйбышевск                                                                                     0.000716
# Кудрово                                                                                            0.000712
# Серпухов                                                                                           0.000712
# Светлогорск                                                                                        0.000712
# Железногорск                                                                                       0.000697
# Гурьевск                                                                                           0.000687
# Ногинск                                                                                            0.000672
# Дмитров                                                                                            0.000672
# Березовский                                                                                        0.000668
# Первоуральск                                                                                       0.000665
# Верхняя Пышма                                                                                      0.000661
# Лобня                                                                                              0.000654
# Каменск-Шахтинский                                                                                 0.000654
# Новоалтайск                                                                                        0.000650
# Долгопрудный                                                                                       0.000647
# Сызрань                                                                                            0.000639
# Котельники                                                                                         0.000639
# Домодедово                                                                                         0.000639
# Азов                                                                                               0.000639
# Всеволожск                                                                                         0.000639
# Ачинск                                                                                             0.000639
# Пушкино                                                                                            0.000636
# Минеральные Воды                                                                                   0.000625
# Бор                                                                                                0.000603
# Кстово                                                                                             0.000596
# Кропоткин                                                                                          0.000581
# Троицк                                                                                             0.000574
# Арзамас                                                                                            0.000570
# Зеленодольск                                                                                       0.000559
# Салават                                                                                            0.000556
# Нефтеюганск                                                                                        0.000556
# Туймазы                                                                                            0.000545
# Солнечногорск                                                                                      0.000545
# Горячий Ключ                                                                                       0.000545
# Сертолово                                                                                          0.000545
# Краснокамск                                                                                        0.000541
# Ленинск-Кузнецкий                                                                                  0.000530
# Щёлково                                                                                            0.000527
# Лыткарино                                                                                          0.000527
# Белореченск                                                                                        0.000519
# Красноармейск                                                                                      0.000516
# Славянск-на-Кубани                                                                                 0.000512
# Камышин                                                                                            0.000501
# Тимашевск                                                                                          0.000494
# Канск                                                                                              0.000490
# Сарапул                                                                                            0.000490
# Киселевск                                                                                          0.000487
# Тихорецк                                                                                           0.000483
# Мосрентген                                                                                         0.000479
# Орехово-Зуево                                                                                      0.000476
# Кирово-Чепецк                                                                                      0.000476
# Гуково                                                                                             0.000476
# Норильск                                                                                           0.000476
# Кинешма                                                                                            0.000472
# Выборг                                                                                             0.000469
# Чехов                                                                                              0.000465
# Лиски                                                                                              0.000461
# Будённовск                                                                                         0.000461
# Ревда                                                                                              0.000461
# Дубна                                                                                              0.000458
# Чебаркуль                                                                                          0.000450
# Яблоновский                                                                                        0.000443
# Щелково                                                                                            0.000432
# Заречный                                                                                           0.000421
# Кумертау                                                                                           0.000418
# Усолье-Сибирское                                                                                   0.000418
# Воскресенское                                                                                      0.000414
# Юрга                                                                                               0.000400
# Серов                                                                                              0.000400
# Воткинск                                                                                           0.000396
# Клин                                                                                               0.000392
# Рубцовск                                                                                           0.000389
# Михайловка                                                                                         0.000385
# Бугульма                                                                                           0.000385
# Белово                                                                                             0.000381
# Соликамск                                                                                          0.000378
# Кунгур                                                                                             0.000378
# Мелеуз                                                                                             0.000378
# Абинск                                                                                             0.000378
# Минусинск                                                                                          0.000374
# Новоуральск                                                                                        0.000371
# Георгиевск                                                                                         0.000371
# Фрязино                                                                                            0.000371
# Нягань                                                                                             0.000367
# Елабуга                                                                                            0.000367
# Сибай                                                                                              0.000367
# Наро-Фоминск                                                                                       0.000367
# Чайковский                                                                                         0.000363
# Елец                                                                                               0.000360
# Зеленоградск                                                                                       0.000360
# Вязьма                                                                                             0.000360
# Московский                                                                                         0.000349
# Ярцево                                                                                             0.000349
# Чистополь                                                                                          0.000349
# Полевской                                                                                          0.000345
# Мегион                                                                                             0.000345
# Ступино                                                                                            0.000341
# Печора                                                                                             0.000338
# Темрюк                                                                                             0.000338
# Новошахтинск                                                                                       0.000338
# Шелехов                                                                                            0.000334
# Южноуральск                                                                                        0.000334
# Северск                                                                                            0.000327
# Кинель                                                                                             0.000327
# Асбест                                                                                             0.000327
# Лениногорск                                                                                        0.000327
# Чусовой                                                                                            0.000327
# Кузнецк                                                                                            0.000323
# Гатчина                                                                                            0.000323
# Рузаевка                                                                                           0.000323
# Переславль-Залесский                                                                               0.000323
# Междуреченск                                                                                       0.000316
# Истра                                                                                              0.000316
# Балашов                                                                                            0.000316
# Егорьевск                                                                                          0.000316
# Кудрово г.                                                                                         0.000316
# Алексин                                                                                            0.000316
# Находка                                                                                            0.000316
# Ишим                                                                                               0.000316
# Глазов                                                                                             0.000312
# Лабинск                                                                                            0.000312
# Арамиль                                                                                            0.000309
# Славгород                                                                                          0.000305
# Павлово                                                                                            0.000301
# Владивосток                                                                                        0.000301
# Луховицы                                                                                           0.000301
# Лесной                                                                                             0.000301
# Осинники                                                                                           0.000301
# Искитим                                                                                            0.000298
# Черняховск                                                                                         0.000298
# Пионерский                                                                                         0.000298
# Кашира                                                                                             0.000298
# Стрежевой                                                                                          0.000294
# Малоярославец                                                                                      0.000294
# Ишимбай                                                                                            0.000294
# Шатура                                                                                             0.000291
# Сальск                                                                                             0.000291
# Чапаевск                                                                                           0.000287
# Белебей                                                                                            0.000283
# Ялуторовск                                                                                         0.000280
# Изобильный                                                                                         0.000280
# Белая Калитва                                                                                      0.000280
# Сысерть                                                                                            0.000276
# Маркова                                                                                            0.000276
# Дюртюли                                                                                            0.000276
# Донской                                                                                            0.000272
# Коркино                                                                                            0.000272
# Каневская                                                                                          0.000272
# Шуя                                                                                                0.000272
# Дзержинский                                                                                        0.000272
# Мыски                                                                                              0.000269
# Слободской                                                                                         0.000269
# Железнодорожный                                                                                    0.000269
# Приморско-Ахтарск                                                                                  0.000265
# Старая Купавна                                                                                     0.000265
# Краснотурьинск                                                                                     0.000265
# Павловский Посад                                                                                   0.000262
# Югорск                                                                                             0.000258
# Россошь                                                                                            0.000258
# Вольск                                                                                             0.000254
# Курганинск                                                                                         0.000254
# Сосновый Бор                                                                                       0.000254
# Можга                                                                                              0.000251
# Каменка                                                                                            0.000247
# Кохма                                                                                              0.000247
# Усинск                                                                                             0.000247
# Красногорск городской округ, Нахабино рп                                                           0.000247
# Железноводск                                                                                       0.000243
# Советск                                                                                            0.000240
# Лысьва                                                                                             0.000240
# Ефремов                                                                                            0.000236
# Азнакаево                                                                                          0.000236
# Среднеуральск                                                                                      0.000236
# Кыштым                                                                                             0.000236
# Апрелевка                                                                                          0.000236
# Усть-Илимск                                                                                        0.000232
# Советский                                                                                          0.000232
# Усть-Лабинск                                                                                       0.000232
# Алексеевка                                                                                         0.000229
# Гулькевичи                                                                                         0.000229
# Сосновоборск                                                                                       0.000229
# Павловск                                                                                           0.000222
# Всеволожский район, Заневское городское поселение, пос. Янино-1                                    0.000218
# Ростов                                                                                             0.000218
# Сафоново                                                                                           0.000218
# Белорецк                                                                                           0.000214
# Балахна                                                                                            0.000214
# Бирск                                                                                              0.000214
# Клинцы                                                                                             0.000214
# Белоярский                                                                                         0.000211
# Десногорск                                                                                         0.000211
# Апшеронск                                                                                          0.000207
# Ростов-на-Дону, Нахичевань                                                                         0.000203
# Ливны                                                                                              0.000203
# Волоколамск                                                                                        0.000203
# Радужный                                                                                           0.000203
# Строитель                                                                                          0.000200
# Шебекино                                                                                           0.000200
# Краснодар городской округ, пос. Российский                                                         0.000200
# Пыть-Ях                                                                                            0.000200
# Анжеро-Судженск                                                                                    0.000200
# Новый Оскол                                                                                        0.000200
# Мценск                                                                                             0.000196
# Реж                                                                                                0.000196
# Краснослободск                                                                                     0.000196
# Щекино                                                                                             0.000196
# Рославль                                                                                           0.000196
# Шарыпово                                                                                           0.000196
# Маркс                                                                                              0.000196
# Ессентукская                                                                                       0.000196
# Щербинка                                                                                           0.000196
# Миллерово                                                                                          0.000196
# Янино-1                                                                                            0.000193
# Урюпинск                                                                                           0.000193
# Брюховецкая                                                                                        0.000193
# Губкин                                                                                             0.000189
# Добрянка                                                                                           0.000189
# Новая Усмань                                                                                       0.000189
# Заринск                                                                                            0.000189
# Качканар                                                                                           0.000185
# Городец                                                                                            0.000185
# Чернушка                                                                                           0.000185
# Ртищево                                                                                            0.000185
# Заводоуковск                                                                                       0.000185
# Высокая Гора                                                                                       0.000185
# Семилуки                                                                                           0.000185
# Узловая                                                                                            0.000185
# Богородицк                                                                                         0.000182
# Янаул                                                                                              0.000182
# Свердлова                                                                                          0.000182
# Кореновск                                                                                          0.000182
# Черемхово                                                                                          0.000182
# Кущевская                                                                                          0.000182
# Городище                                                                                           0.000178
# Донецк                                                                                             0.000178
# Вичуга                                                                                             0.000178
# Яхрома                                                                                             0.000174
# Северская                                                                                          0.000174
# Красногорск городской округ, д. Путилково                                                          0.000171
# Озерск                                                                                             0.000171
# Великий Устюг                                                                                      0.000171
# Дегтярск                                                                                           0.000171
# Углич                                                                                              0.000171
# Вятские Поляны                                                                                     0.000171
# Озёры                                                                                              0.000167
# Голицыно                                                                                           0.000167
# Мариинск                                                                                           0.000167
# Ирбит                                                                                              0.000167
# Новозыбков                                                                                         0.000167
# Куровское                                                                                          0.000163
# Ипатово                                                                                            0.000163
# Борисоглебск                                                                                       0.000163
# Мостовской                                                                                         0.000163
# Учалы                                                                                              0.000163
# Морозовск                                                                                          0.000163
# Люберцы городской округ, Октябрьский рп                                                            0.000160
# Агрыз                                                                                              0.000160
# Острогожск                                                                                         0.000160
# Хотьково                                                                                           0.000160
# Похвистнево                                                                                        0.000160
# Верхняя Салда                                                                                      0.000160
# Петровск                                                                                           0.000160
# Комсомольск                                                                                        0.000160
# Лесосибирск                                                                                        0.000160
# Камень-на-Оби                                                                                      0.000160
# Светлоград                                                                                         0.000156
# Омутнинск                                                                                          0.000156
# Назарово                                                                                           0.000156
# Кушва                                                                                              0.000156
# Давлеканово                                                                                        0.000156
# Новокубанск                                                                                        0.000156
# Невьянск                                                                                           0.000156
# Краснообск                                                                                         0.000156
# Жигулевск                                                                                          0.000153
# Красноуфимск                                                                                       0.000153
# Нерехта                                                                                            0.000153
# Топки                                                                                              0.000153
# Кингисепп                                                                                          0.000153
# Красный Сулин                                                                                      0.000149
# Воркута                                                                                            0.000149
# Выкса                                                                                              0.000149
# Люберцы городской округ, пос. Мирный, Томилино Парк ЖК                                             0.000149
# Светлый                                                                                            0.000149
# Ленинградская                                                                                      0.000149
# Егорлыкская                                                                                        0.000149
# Алапаевск                                                                                          0.000149
# Ершов                                                                                              0.000149
# Сердобск                                                                                           0.000145
# Валуйки                                                                                            0.000145
# Сухой Лог                                                                                          0.000145
# Кириши                                                                                             0.000145
# Кочубеевское                                                                                       0.000145
# Тогучин                                                                                            0.000145
# Полтавская                                                                                         0.000142
# Зеленокумск                                                                                        0.000142
# Богданович                                                                                         0.000142
# Тутаев                                                                                             0.000142
# Ленинский городской округ, д. Мисайлово                                                            0.000142
# Павловская                                                                                         0.000142
# Нурлат                                                                                             0.000142
# Шахунья                                                                                            0.000142
# Нововоронеж                                                                                        0.000142
# Новоалександровск                                                                                  0.000142
# Динская                                                                                            0.000142
# Засечное                                                                                           0.000138
# Дубовое                                                                                            0.000138
# Фролово                                                                                            0.000138
# Дивногорск                                                                                         0.000138
# Благовещенск                                                                                       0.000138
# Урай                                                                                               0.000138
# Южный                                                                                              0.000138
# Бавлы                                                                                              0.000138
# Одинцовский городской округ, пос. ВНИИССОК                                                         0.000138
# Нижний Ломов                                                                                       0.000138
# Усть-Кут                                                                                           0.000134
# Заинск                                                                                             0.000134
# Балтийск                                                                                           0.000134
# Когалым                                                                                            0.000134
# Цимлянск                                                                                           0.000134
# Заволжье                                                                                           0.000134
# Лангепас                                                                                           0.000134
# Коммунар                                                                                           0.000131
# Фурманов                                                                                           0.000131
# Усмань                                                                                             0.000131
# Родники                                                                                            0.000131
# ...
# посёлок Лазурный                                                                                   0.000004
# Агаповский район, пос. Первомайский                                                                0.000004
# Красносельский район, с. Сидоровское                                                               0.000004
# Крымский район, Адагум хут.                                                                        0.000004
# Советский район, Степное пгт                                                                       0.000004
# Пензенский район, с. Богословка                                                                    0.000004
# Краснинский район, д. Маньково                                                                     0.000004
# Кстовский район, д. Подлесово                                                                      0.000004
# Мошковский район, пос. Радуга                                                                      0.000004
# Ставропольский район                                                                               0.000004
# Туапсинский район, с. Индюк                                                                        0.000004
# Солонешное                                                                                         0.000004
# Солнечногорск городской округ, д. Лыткино                                                          0.000004
# рабочий посёлок Хорлово                                                                            0.000004
# Тевриз                                                                                             0.000004
# Новогорск                                                                                          0.000004
# Петрово                                                                                            0.000004
# Объячево                                                                                           0.000004
# Русский Камешкир                                                                                   0.000004
# Архангельский район, д. Новоустиновка                                                              0.000004
# посёлок городского типа Подосиновец                                                                0.000004
# Истра городской округ, д. Корсаково                                                                0.000004
# Лодейнопольский район, пос. Свирьстрой                                                             0.000004
# Мытищи городской округ, пос. Нагорное, Нехлюдово кп                                                0.000004
# Пушкинский городской округ, Лесной рп, Квартал в Лесном ЖК                                         0.000004
# Большое Жирово                                                                                     0.000004
# Северск городской округ, Сосновка мкр                                                              0.000004
# Гвардейский городской округ                                                                        0.000004
# Красногорск городской округ, с. Николо-Урюпино, Новахово кп                                        0.000004
# Миасс городской округ, пос. Тургояк, Некоммерческое партнерство Пансионат Тургояк тер.             0.000004
# Приладожский                                                                                       0.000004
# Неманский городской округ, пос. Мичуринский                                                        0.000004
# Тюменский район, с. Каменка                                                                        0.000004
# Ленинский городской округ, д. Сапроново, Купелинка мкр, Северный кв-л                              0.000004
# Ломоносовский район, Лебяженское городское поселение, Лебяжье городской поселок                    0.000004
# Малоярославецкий район, Деревня Михеево с/пос, д. Михеево                                          0.000004
# Успенский район, с. Марьино                                                                        0.000004
# Одинцовский городской округ, пос. Заречье                                                          0.000004
# Лаишевский район, с. Большие Кабаны                                                                0.000004
# Красноярский район, пос. Угловой                                                                   0.000004
# Двубратский                                                                                        0.000004
# Элита                                                                                              0.000004
# Кавалерово                                                                                         0.000004
# Брянский район, Снежское с/пос, с. Толмачево                                                       0.000004
# посёлок городского типа Красная Поляна                                                             0.000004
# Высокогорский район, с. Куркачи                                                                    0.000004
# Всеволожский район, Колтушское с/пос, д. Старая, Колтуши 5+ ЖК                                     0.000004
# Луховицы городской округ, пос. Газопроводск                                                        0.000004
# Пермский район, пос. Сылва                                                                         0.000004
# Зимовниковский район, пос. Зимовники                                                               0.000004
# Грахово                                                                                            0.000004
# Приозерский район, пос. Сосново                                                                    0.000004
# поселок Третий Северный                                                                            0.000004
# Убинский район, с. Убинское                                                                        0.000004
# Верхняя Пышма городской округ, Восточное СНТ                                                       0.000004
# Ульяновск городской округ, с. Белый Ключ                                                           0.000004
# Томский район, д. Карбышево                                                                        0.000004
# Спицевка                                                                                           0.000004
# Дмитровский городской округ, пос. Новонекрасовский                                                 0.000004
# Северский район, с. Львовское                                                                      0.000004
# посёлок городского типа Голышманово                                                                0.000004
# Дубовский район, с. Пичуга                                                                         0.000004
# Алнаши                                                                                             0.000004
# Коломенский городской округ, пос. Пески                                                            0.000004
# Красносельский район, Красное-на-Волге пгт, Восточный мкр                                          0.000004
# Гулькевичский район, Венцы-Заря с/пос, пос. Венцы                                                  0.000004
# Долгоруковский район, с. Долгоруково                                                               0.000004
# Богородский городской округ, пос. Зеленый                                                          0.000004
# Санаторий Истра                                                                                    0.000004
# Череповецкий район, пос. Тоншалово                                                                 0.000004
# Обшаровка                                                                                          0.000004
# городской округ Люберцы                                                                            0.000004
# Лосино-Петровский городской округ, пос. Юность                                                     0.000004
# Дзержинский район, Поселок Пятовский городское поселение, пос. Пятовский                           0.000004
# Андроповский район, с. Курсавка                                                                    0.000004
# село Шумейка                                                                                       0.000004
# Сотниковское                                                                                       0.000004
# Шебекинский городской округ, с. Ржевка                                                             0.000004
# Хлевенский район, с. Конь-Колодезь                                                                 0.000004
# Дмитровский городской округ, д. Каменка                                                            0.000004
# Динской район, с. Красносельское                                                                   0.000004
# Тосненский район, Тельмановское с/пос, д. Ям-Ижора                                                 0.000004
# Дмитровский городской округ                                                                        0.000004
# Мелекесский район, Мулловка пгт                                                                    0.000004
# городской посёлок Токсово                                                                          0.000004
# Пряжинский район, пос. Чална                                                                       0.000004
# Краснодар городской округ, пос. отделения № 3 СКЗНИИСиВ                                            0.000004
# поселок Новый Учхоз                                                                                0.000004
# Березники муниципальное образование Город, д. Пешково                                              0.000004
# Кадошкинский район, Кадошкино рп                                                                   0.000004
# Летка                                                                                              0.000004
# посёлок Аннино                                                                                     0.000004
# посёлок Радужный                                                                                   0.000004
# Таврово                                                                                            0.000004
# Усть-Вымский район, с. Айкино                                                                      0.000004
# Голышмановский городской округ, Голышманово пгт                                                    0.000004
# Уфимский район, Таптыковский с/с, с. Таптыково                                                     0.000004
# Лужский район, Ретюнское с/пос, д. Елемцы                                                          0.000004
# Гагаринский район, д. Усилительный Пункт                                                           0.000004
# Среднеахтубинский район                                                                            0.000004
# Гвардейский городской округ, пос. Славинск                                                         0.000004
# Переславль-Залесский городской округ, с. Веськово                                                  0.000004
# Городищенский район, пос. Новая Надежда                                                            0.000004
# Предгорный муниципальный округ, с. Винсады                                                         0.000004
# Березовский городской округ, пос. Лосиный                                                          0.000004
# посёлок Большевик                                                                                  0.000004
# Заостровье                                                                                         0.000004
# Краснодар городской округ, Радужное садовое товарищество                                           0.000004
# Волжский район, Облвоенкомат СНТ                                                                   0.000004
# Домодедово городской округ, д. Котляково                                                           0.000004
# Гурьевский городской округ, пос. Заозерье                                                          0.000004
# Ялуторовский район, с. Памятное                                                                    0.000004
# Сосновский район, д. Касарги                                                                       0.000004
# Луховицы городской округ, пос. Сельхозтехника                                                      0.000004
# Новосибирский район, с. Криводановка                                                               0.000004
# Нижнедевицкий район, пос. Курбатово                                                                0.000004
# посёлок Дорохово                                                                                   0.000004
# Гурьевский городской округ, Рублевочка ДНП                                                         0.000004
# Черкизово                                                                                          0.000004
# Ленинское                                                                                          0.000004
# Ивановский район, Богданихское с/пос                                                               0.000004
# Омутинский район, д. Новодеревенская                                                               0.000004
# Новосибирский район, пос. Восход                                                                   0.000004
# Одинцовский городской округ, пос. Санатория имени Герцена                                          0.000004
# Волоколамский городской округ, с. Ярополец                                                         0.000004
# город Семилуки                                                                                     0.000004
# Мытищи городской округ, д. Погорелки                                                               0.000004
# Ивот                                                                                               0.000004
# посёлок Юг                                                                                         0.000004
# Богородский район, с. Доскино                                                                      0.000004
# деревня Подосинки                                                                                  0.000004
# Дмитровский городской округ, с. Ильинское                                                          0.000004
# Строителей 4                                                                                       0.000004
# Барнаул городской округ, пос. Черницк                                                              0.000004
# Ивановский район, Новоталицкое с/пос, д. Голчаново                                                 0.000004
# посёлок Нижний Кучук                                                                               0.000004
# Панинский район, пос. Перелешино                                                                   0.000004
# Урай городской округ, 1-й мкр                                                                      0.000004
# Мытищи городской округ, д. Высоково                                                                0.000004
# городской округ Чехов                                                                              0.000004
# Кинель-Черкасский район, с. Кабановка                                                              0.000004
# Таврово-1                                                                                          0.000004
# Луговое                                                                                            0.000004
# Выселковский район, Выселки ст-ца                                                                  0.000004
# Сочи городской округ, с. Волковка                                                                  0.000004
# Малоярославецкий район, Деревня Ерденево с/пос, д. Ерденево                                        0.000004
# деревня Каменка                                                                                    0.000004
# Name: city, dtype: float64

# %%
def isMediumCity(name):
  return cityFrequency[name] >= 0.005 and cityFrequency[name] < 0.015

def isSmallCity(name):
  return cityFrequency[name] >= 0.001 and cityFrequency[name] < 0.005 

def isLittleCity(name):
  return cityFrequency[name] >= 0.001 and cityFrequency[name] < 0.005 

df = df.assign(
  city_moskow=((df.city == "Москва")).astype(int),
  city_saint_petersburg=((df.city == "Санкт-Петербург")).astype(int),
  city_krasnodar=((df.city == "Краснодар")).astype(int),
  city_ekaterinburg=((df.city == "Екатеринбург")).astype(int),
  city_novosibirsk=((df.city == "Новосибирск")).astype(int),
  city_chelyabinsk=((df.city == "Челябинск")).astype(int),
  city_samara=((df.city == "Самара")).astype(int),
  city_kazan=((df.city == "Казань")).astype(int),
  city_tymen=((df.city == "Тюмень")).astype(int),
  city_ufa=((df.city == "Уфа")).astype(int),
  city_nino=((df.city == "Нижний Новгород")).astype(int),
  city_rod=((df.city == "Ростов-на-Дону")).astype(int),
  city_medium=((df.city.apply(isMediumCity))).astype(int),
  city_small=((df.city.apply(isSmallCity))).astype(int),
  city_little=((df.city.apply(isLittleCity))).astype(int)
)

# %%
def amenityDependency(in100m, in500m, in750m, in1000m):
  return in100m ** 1.5 + (in500m - in100m) ** 0.8 + (in750m - in500m) ** 0.6 + (in1000m - in750m) ** 0.4

# %%
df = df.assign(
  amenity=df.apply(lambda row: amenityDependency(row['osm_amenity_points_in_0.001'], 
                                                  row['osm_amenity_points_in_0.005'],
                                                  row['osm_amenity_points_in_0.0075'],
                                                  row['osm_amenity_points_in_0.01']), 
                    axis=1)
)

# %%
df.amenity.hist(bins=50)
plt.show()

# %%
from math import log1p
df = df.assign(
  amenity_ln=df.amenity.apply(log1p)
)

# %%
df.amenity_ln.hist(bins=50)
plt.show()

# %%
def medcouple(x):
  Q2 = x.quantile(q=0.5)
  dist = np.asarray([])
  for i in range(0, len(x)):
    for j in range(0, len(x)):
      if x[i] != x[j] and x[i] <= Q2 and x[j] < Q2:
        np.append(dist, (x[j] - Q2) - (Q2 - x[i])) / (x[j] - x[i])
  return dist.median()

# %%
median = df.amenity_ln.median()
print(median)
df = df.assign(
  amenity_ln_center=df.amenity_ln.apply(lambda x: x - median)
)
# Out:
# 3.232528608117638

# %%
df.amenity_ln_center.hist(bins=50)
plt.show()

# %%
q25, q75 = df.amenity_ln_center.quantile(q=0.25), df.amenity_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)
# Out:
# q25 = -0.6867438168067945
# q75 = 0.5941382782861746

# %%
median = df.amenity_ln_center.median()
df = df.assign(
  amenity_ln_center_norm=df.amenity_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50)
plt.show()

# %%
df.boxplot(['osm_building_points_in_0.001',
            'osm_building_points_in_0.005',
            'osm_building_points_in_0.0075',
            'osm_building_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  osm_building_points_modified_in_0_001=df['osm_building_points_in_0.001'] / 5.0,
  osm_building_points_modified_in_0_005=df['osm_building_points_in_0.005'].apply(log1p),
  osm_building_points_modified_in_0_0075=df['osm_building_points_in_0.0075'].apply(log1p),
  osm_building_points_modified_in_0_01=df['osm_building_points_in_0.01'].apply(log1p),
)

df.boxplot(['osm_building_points_modified_in_0_001',
            'osm_building_points_modified_in_0_005',
            'osm_building_points_modified_in_0_0075',
            'osm_building_points_modified_in_0_01'
])
plt.show()

# %%
def buildingDependency(in100m, in500m, in750m, in1000m):
  return in100m  * 0.4 + (in500m - in100m) ** 0.6 + (in750m - in500m) ** 0.8 + (in1000m - in750m) ** 1.5

# %%
df = df.assign(
  building=df.apply(lambda row: buildingDependency(row['osm_building_points_in_0.001'],
                                                    row['osm_building_points_in_0.005'],
                                                    row['osm_building_points_in_0.0075'],
                                                    row['osm_building_points_in_0.01']), 
                    axis=1)
  )

df.building.hist(bins=50)
plt.show()

df.boxplot('building')
plt.show()

# %%
import math

df = df.assign(
  building_ln=df.building.apply(lambda x: math.log(x + 1, 15000))
)
df.building_ln.hist(bins=50)
plt.show()

df.boxplot('building_ln')
plt.show()

# %% [markdown]
# :(

# %%
df.boxplot(['osm_catering_points_in_0.001',
            'osm_catering_points_in_0.005',
            'osm_catering_points_in_0.0075',
            'osm_catering_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  catering=df.apply(lambda row: amenityDependency(row['osm_catering_points_in_0.001'], 
                                                  row['osm_catering_points_in_0.005'],
                                                  row['osm_catering_points_in_0.0075'],
                                                  row['osm_catering_points_in_0.01']), 
                    axis=1)
)
df.catering.hist(bins=50)
plt.show()

# %%
df = df.assign(
  catering_ln=df.catering.apply(log1p)
)
df.catering_ln.hist(bins=50)
plt.show()

# %%
median = df.catering_ln.median()
print(median)
df = df.assign(
  catering_ln_center=df.catering_ln.apply(lambda x: x - median)
)
df.catering_ln_center.hist(bins=50)
plt.show()
# Out:
# 1.8336717001210219

# %%
q25, q75 = df.catering_ln_center.quantile(q=0.25), df.catering_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.catering_ln_center.median()
df = df.assign(
  catering_ln_center_norm=df.catering_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity')
df.catering_ln_center_norm.hist(bins=50, label='catering')
plt.legend()
plt.show()
# Out:
# q25 = -0.7350594114529123
# q75 = 0.6722777430595754

# %%
df.boxplot('osm_city_closest_dist')
plt.show()

# %%
df = df.assign(
  city_closest_dist_ln=df.osm_city_closest_dist.apply(log1p)
)
df.city_closest_dist_ln.hist(bins=50)
plt.show()

# %%
median = df.city_closest_dist_ln.median()
print(median)
df = df.assign(
  city_closest_dist_ln_center=df.city_closest_dist_ln.apply(lambda x: x - median)
)
df.city_closest_dist_ln_center.hist(bins=50)
plt.show()
# Out:
# 1.8557692081607846

# %%
q25, q75 = df.city_closest_dist_ln_center.quantile(q=0.25), df.city_closest_dist_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.city_closest_dist_ln_center.median()
df = df.assign(
  city_closest_dist_ln_center_norm=df.city_closest_dist_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
plt.legend()
plt.show()
# Out:
# q25 = -0.5751527337405891
# q75 = 0.6163196313745958

# %%
nearestCityFrequency = df.osm_city_nearest_name.value_counts(normalize=True)
print(nearestCityFrequency)

def isMediumNearestCity(name):
  return nearestCityFrequency[name] >= 0.005 and nearestCityFrequency[name] <= 0.018

def isSmallNearestCity(name):
  return nearestCityFrequency[name] >= 0.001 and nearestCityFrequency[name] < 0.005 

def isLittleNearestCity(name):
  return nearestCityFrequency[name] >= 0.001 and nearestCityFrequency[name] < 0.005 

df = df.assign(
  nearest_city_moskow=((df.osm_city_nearest_name == "Москва")).astype(int),
  nearest_city_saint_petersburg=((df.osm_city_nearest_name == "Санкт-Петербург")).astype(int),
  nearest_city_krasnodar=((df.osm_city_nearest_name == "Краснодар")).astype(int),
  nearest_city_ekaterinburg=((df.osm_city_nearest_name == "Екатеринбург")).astype(int),
  nearest_city_novosibirsk=((df.osm_city_nearest_name == "Новосибирск")).astype(int),
  nearest_city_chelyabinsk=((df.osm_city_nearest_name == "Челябинск")).astype(int),
  nearest_city_samara=((df.osm_city_nearest_name == "Самара")).astype(int),
  nearest_city_kazan=((df.osm_city_nearest_name == "Казань")).astype(int),
  nearest_city_tymen=((df.osm_city_nearest_name == "Тюмень")).astype(int),
  nearest_city_podolsk=((df.osm_city_nearest_name == "Подольск")).astype(int),
  nearest_city_ufa=((df.osm_city_nearest_name == "Уфа")).astype(int),
  nearest_city_nino=((df.osm_city_nearest_name == "Нижний Новгород")).astype(int),
  nearest_city_rod=((df.osm_city_nearest_name == "Ростов-на-Дону")).astype(int),
  nearest_city_medium=((df.osm_city_nearest_name.apply(isMediumNearestCity))).astype(int),
  nearest_city_small=((df.osm_city_nearest_name.apply(isSmallNearestCity))).astype(int),
  nearest_city_little=((df.osm_city_nearest_name.apply(isLittleNearestCity))).astype(int)
)
# Out:
# Москва               0.133825
# Санкт-Петербург      0.067341
# Краснодар            0.053070
# Екатеринбург         0.033771
# Челябинск            0.025507
# Новосибирск          0.024028
# Самара               0.023709
# Казань               0.023622
# Тюмень               0.023069
# Подольск             0.022172
# Нижний Новгород      0.019539
# Уфа                  0.019328
# Ростов-на-Дону       0.018692
# Пермь                0.016949
# Воронеж              0.016357
# Люберцы              0.016004
# Новороссийск         0.014984
# Красноярск           0.014370
# Химки                0.014126
# Калининград          0.012946
# Ставрополь           0.011762
# Саратов              0.011152
# Одинцово             0.010999
# Долгопрудный         0.010294
# Сочи                 0.009644
# Волгоград            0.009437
# Красногорск          0.009263
# Омск                 0.009019
# Иркутск              0.008936
# Мытищи               0.008874
# Барнаул              0.008747
# Ижевск               0.007933
# Пенза                0.007185
# Кемерово             0.007094
# Белгород             0.006880
# Киров                0.006640
# Ярославль            0.006513
# Ульяновск            0.006175
# Иваново              0.006048
# Брянск               0.005863
# Тула                 0.005855
# Тольятти             0.005765
# Смоленск             0.005074
# Зеленоград           0.004962
# Сыктывкар            0.004958
# Колпино              0.004911
# Новокузнецк          0.004900
# Липецк               0.004889
# Нижний Тагил         0.004704
# Пятигорск            0.004537
# Набережные Челны     0.004526
# Кострома             0.004461
# Сургут               0.004399
# Томск                0.004134
# Балашиха             0.004083
# Королёв              0.004079
# Пушкин               0.003883
# Альметьевск          0.003839
# Домодедово           0.003836
# Таганрог             0.003607
# Орёл                 0.003578
# Магнитогорск         0.003305
# Армавир              0.003269
# Бердск               0.003269
# Калуга               0.003269
# Вологда              0.003258
# Нижневартовск        0.003218
# Курск                0.003197
# Саранск              0.003164
# Дзержинск            0.003157
# Майкоп               0.003142
# Обнинск              0.003084
# Петрозаводск         0.003055
# Волжский             0.002917
# Шахты                0.002870
# Каменск-Уральский    0.002644
# Старый Оскол         0.002634
# Энгельс              0.002597
# Сергиев Посад        0.002550
# Волгодонск           0.002543
# Миасс                0.002477
# Нижнекамск           0.002470
# Череповец            0.002430
# Нефтекамск           0.002354
# Стерлитамак          0.002292
# Первоуральск         0.002259
# Щёлково              0.002219
# Прокопьевск          0.002169
# Серпухов             0.002165
# Коломна              0.002052
# Электросталь         0.001991
# Братск               0.001932
# Ангарск              0.001903
# Балаково             0.001871
# Салават              0.001838
# Рубцовск             0.001831
# Батайск              0.001827
# Ханты-Мансийск       0.001765
# Златоуст             0.001740
# Жуковский            0.001595
# Тобольск             0.001562
# Березники            0.001558
# Пушкино              0.001551
# Серов                0.001504
# Ессентуки            0.001460
# Новочеркасск         0.001446
# Бийск                0.001435
# Новомосковск         0.001391
# Рыбинск              0.001348
# Новокуйбышевск       0.001290
# Новошахтинск         0.001279
# Тамбов               0.001279
# Раменское            0.001253
# Арзамас              0.001235
# Ачинск               0.001231
# Воскресенск          0.001224
# Орехово-Зуево        0.001217
# Кисловодск           0.001188
# Димитровград         0.001159
# Невинномысск         0.001137
# Сызрань              0.001101
# Воткинск             0.001068
# Камышин              0.001050
# Кирово-Чепецк        0.001021
# Елец                 0.000977
# Ногинск              0.000966
# Нефтеюганск          0.000955
# Северск              0.000701
# Глазов               0.000657
# Нарьян-Мар           0.000654
# Абакан               0.000632
# Узловая              0.000574
# Норильск             0.000552
# Тверь                0.000548
# Сарапул              0.000523
# Соликамск            0.000469
# Белорецк             0.000454
# Находка              0.000414
# Муром                0.000407
# Владивосток          0.000320
# Йошкар-Ола           0.000316
# Керчь                0.000294
# Уссурийск            0.000276
# Псков                0.000265
# Воркута              0.000240
# Назрань              0.000214
# Великий Новгород     0.000214
# Элиста               0.000203
# Салехард             0.000200
# 饶河县                  0.000196
# Владимир             0.000174
# Горно-Алтайск        0.000167
# Чебоксары            0.000145
# Ковров               0.000145
# Рязань               0.000142
# Ноябрьск             0.000138
# Нальчик              0.000134
# Артём                0.000116
# Черкесск             0.000084
# Грозный              0.000076
# Улан-Удэ             0.000054
# Орск                 0.000051
# 绥芬河市                 0.000047
# Мурманск             0.000044
# Чита                 0.000029
# Великие Луки         0.000029
# Курган               0.000022
# Магадан              0.000011
# Новый Уренгой        0.000007
# Новочебоксарск       0.000007
# Name: osm_city_nearest_name, dtype: float64

# %%
# mean, std = df.osm_city_nearest_population.apply(log1p).mean(), df.osm_city_nearest_population.apply(log1p).std()
# print(mean, std)
# df.osm_city_nearest_population.apply(lambda x: ((x + mean) / std)).hist(bins=50)
# plt.show()

# %%
df.boxplot(['osm_crossing_points_in_0.001',
            'osm_crossing_points_in_0.005',
            'osm_crossing_points_in_0.0075',
            'osm_crossing_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  crossing=df.apply(lambda row: amenityDependency(row['osm_crossing_points_in_0.001'], 
                                                    row['osm_crossing_points_in_0.005'],
                                                    row['osm_crossing_points_in_0.0075'],
                                                    row['osm_crossing_points_in_0.01']), 
                    axis=1)
)
df.crossing.hist(bins=50)
plt.show()

# %%
df = df.assign(
  crossing_ln=df.crossing.apply(log1p)
)
df.crossing_ln.hist(bins=50)
plt.show()

median = df.crossing_ln.median()
print(median)
df = df.assign(
  crossing_ln_center=df.crossing_ln.apply(lambda x: x - median)
)
df.crossing_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.crossing_ln_center.quantile(q=0.25), df.crossing_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.crossing_ln_center.median()
df = df.assign(
  crossing_ln_center_norm=df.crossing_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
df.crossing_ln_center_norm.hist(bins=50, label='crossing', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 2.6617110680957854
# q25 = -0.6838105730995612
# q75 = 0.4684451199657451

# %% [markdown]
# culture_points kinda :(

# %%
df.boxplot(['osm_finance_points_in_0.001',
            'osm_finance_points_in_0.005',
            'osm_finance_points_in_0.0075',
            'osm_finance_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  finance=df.apply(lambda row: amenityDependency(row['osm_finance_points_in_0.001'], 
                                                  row['osm_finance_points_in_0.005'],
                                                  row['osm_finance_points_in_0.0075'],
                                                  row['osm_finance_points_in_0.01']), 
                    axis=1)
)
df.finance.hist(bins=50)
plt.show()

# %% [markdown]
# finance_points :(

# %%
df.boxplot(['osm_healthcare_points_in_0.005',
            'osm_healthcare_points_in_0.0075',
            'osm_healthcare_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  healthcare=df.apply(lambda row: amenityDependency(row['osm_healthcare_points_in_0.005'],
                                                    row['osm_healthcare_points_in_0.0075'],
                                                    row['osm_healthcare_points_in_0.01'], 
                                                    row['osm_healthcare_points_in_0.01']), 
                    axis=1)
)
df.healthcare.hist(bins=50)
plt.show()

# %% [markdown]
# healthcare :(

# %% [markdown]
# historic :(

# %% [markdown]
# hotels :(

# %%
# osm_leisure_points
df.boxplot(['osm_leisure_points_in_0.005',
            'osm_leisure_points_in_0.0075',
            'osm_leisure_points_in_0.01'
])
plt.show()

# %%
def leisureDependency(in500m, in750m, in1000m):
  return in500m 

df = df.assign(
  leisure=df.apply(lambda row: leisureDependency(row['osm_leisure_points_in_0.005'],
                                                  row['osm_leisure_points_in_0.0075'],
                                                  row['osm_leisure_points_in_0.01']), 
                    axis=1)
)
df.leisure.hist(bins=50)
plt.show()

# %%
df = df.assign(
  leisure_ln=df.leisure.apply(log1p)
)
df.leisure_ln.hist(bins=50)
plt.show()

median = df.leisure_ln.median()
print(median)
df = df.assign(
  leisure_ln_center=df.leisure_ln.apply(lambda x: x - median)
)
df.leisure_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.leisure_ln_center.quantile(q=0.25), df.leisure_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.leisure_ln_center.median()
df = df.assign(
  leisure_ln_center_norm=df.leisure_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
df.crossing_ln_center_norm.hist(bins=50, label='crossing', alpha=0.5)
# df.shops_ln_center_norm.hist(bins=50, label='shops', alpha=0.5)
df.leisure_ln_center_norm.hist(bins=50, label='leisure', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 0.6931471805599453
# q25 = -0.6931471805599453
# q75 = 0.6931471805599453

# %% [markdown]
# leisure :(

# %% [markdown]
# offices :(

# %%
df.boxplot(['osm_shops_points_in_0.001',
            'osm_shops_points_in_0.005',
            'osm_shops_points_in_0.0075',
            'osm_shops_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  shops=df.apply(lambda row: amenityDependency(row['osm_shops_points_in_0.001'], 
                                                row['osm_shops_points_in_0.005'],
                                                row['osm_shops_points_in_0.0075'],
                                                row['osm_shops_points_in_0.01']), 
                    axis=1)
)
df.shops.hist(bins=50)
plt.show()

# %%
df = df.assign(
  shops_ln=df.shops.apply(log1p)
)
df.shops_ln.hist(bins=50)
plt.show()

median = df.shops_ln.median()
print(median)
df = df.assign(
  shops_ln_center=df.shops_ln.apply(lambda x: x - median)
)
df.shops_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.shops_ln_center.quantile(q=0.25), df.shops_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.shops_ln_center.median()
df = df.assign(
  shops_ln_center_norm=df.shops_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
df.crossing_ln_center_norm.hist(bins=50, label='crossing', alpha=0.5)
df.shops_ln_center_norm.hist(bins=50, label='shops', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 2.87123572866897
# q25 = -0.687353542990794
# q75 = 0.5518612918124632

# %%
df.boxplot('osm_subway_closest_dist')
plt.show()

# %%
df[df.osm_subway_closest_dist < 500].osm_subway_closest_dist.hist()
plt.show()

# %%
df = df.assign(
  subway_in_100m=((df.osm_subway_closest_dist <= 100)).astype(int),
  subway_in_500m=((100 < df.osm_subway_closest_dist) & (df.osm_subway_closest_dist <= 500)).astype(int),
  subway_in_1500m=((500 < df.osm_subway_closest_dist) & (df.osm_subway_closest_dist <= 1500)).astype(int),
  subway_far_away=((1500 < df.osm_subway_closest_dist)).astype(int),
)

# %%
df.boxplot('osm_train_stop_closest_dist')
plt.show()

# %%
df[df.osm_train_stop_closest_dist < 50].osm_train_stop_closest_dist.hist(bins=50)
plt.show()
print(df[df.osm_train_stop_closest_dist < 50].osm_train_stop_closest_dist.quantile(q=0.75))
# Out:
# 5.120800021084878

# %%
df = df.assign(
  train_stop_in_1_5=((df.osm_train_stop_closest_dist <= 1.5)).astype(int),
  train_stop_in_2_55=((1.5 < df.osm_train_stop_closest_dist) & (df.osm_train_stop_closest_dist <= 2.55)).astype(int),
  train_stop_in_5_2=((2.55 < df.osm_train_stop_closest_dist) & (df.osm_train_stop_closest_dist <= 5_2)).astype(int),
  train_stop_far_away=((5.2 < df.osm_train_stop_closest_dist)).astype(int)
)

# %% [markdown]
# train_stop_points skip

# %%
df.to_csv('processed_data/11-test-features.csv', index=False)
