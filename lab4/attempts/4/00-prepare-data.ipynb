# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = (10, 5)

# %%
df = pd.read_csv('data/train.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206474 entries, 0 to 206473
# Data columns (total 76 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   city                                 206474 non-null  object
#  1   floor                                76209 non-null   float64
#  2   id                                   206474 non-null  object
#  3   lat                                  206474 non-null  float64
#  4   lng                                  206474 non-null  float64
#  5   osm_amenity_points_in_0.001          206474 non-null  int64
#  6   osm_amenity_points_in_0.005          206474 non-null  int64
#  7   osm_amenity_points_in_0.0075         206474 non-null  int64
#  8   osm_amenity_points_in_0.01           206474 non-null  int64
#  9   osm_building_points_in_0.001         206474 non-null  int64
#  10  osm_building_points_in_0.005         206474 non-null  int64
#  11  osm_building_points_in_0.0075        206474 non-null  int64
#  12  osm_building_points_in_0.01          206474 non-null  int64
#  13  osm_catering_points_in_0.001         206474 non-null  int64
#  14  osm_catering_points_in_0.005         206474 non-null  int64
#  15  osm_catering_points_in_0.0075        206474 non-null  int64
#  16  osm_catering_points_in_0.01          206474 non-null  int64
#  17  osm_city_closest_dist                206474 non-null  float64
#  18  osm_city_nearest_name                206474 non-null  object
#  19  osm_city_nearest_population          206439 non-null  float64
#  20  osm_crossing_closest_dist            206474 non-null  float64
#  21  osm_crossing_points_in_0.001         206474 non-null  int64
#  22  osm_crossing_points_in_0.005         206474 non-null  int64
#  23  osm_crossing_points_in_0.0075        206474 non-null  int64
#  24  osm_crossing_points_in_0.01          206474 non-null  int64
#  25  osm_culture_points_in_0.001          206474 non-null  int64
#  26  osm_culture_points_in_0.005          206474 non-null  int64
#  27  osm_culture_points_in_0.0075         206474 non-null  int64
#  28  osm_culture_points_in_0.01           206474 non-null  int64
#  29  osm_finance_points_in_0.001          206474 non-null  int64
#  30  osm_finance_points_in_0.005          206474 non-null  int64
#  31  osm_finance_points_in_0.0075         206474 non-null  int64
#  32  osm_finance_points_in_0.01           206474 non-null  int64
#  33  osm_healthcare_points_in_0.005       206474 non-null  int64
#  34  osm_healthcare_points_in_0.0075      206474 non-null  int64
#  35  osm_healthcare_points_in_0.01        206474 non-null  int64
#  36  osm_historic_points_in_0.005         206474 non-null  int64
#  37  osm_historic_points_in_0.0075        206474 non-null  int64
#  38  osm_historic_points_in_0.01          206474 non-null  int64
#  39  osm_hotels_points_in_0.005           206474 non-null  int64
#  40  osm_hotels_points_in_0.0075          206474 non-null  int64
#  41  osm_hotels_points_in_0.01            206474 non-null  int64
#  42  osm_leisure_points_in_0.005          206474 non-null  int64
#  43  osm_leisure_points_in_0.0075         206474 non-null  int64
#  44  osm_leisure_points_in_0.01           206474 non-null  int64
#  45  osm_offices_points_in_0.001          206474 non-null  int64
#  46  osm_offices_points_in_0.005          206474 non-null  int64
#  47  osm_offices_points_in_0.0075         206474 non-null  int64
#  48  osm_offices_points_in_0.01           206474 non-null  int64
#  49  osm_shops_points_in_0.001            206474 non-null  int64
#  50  osm_shops_points_in_0.005            206474 non-null  int64
#  51  osm_shops_points_in_0.0075           206474 non-null  int64
#  52  osm_shops_points_in_0.01             206474 non-null  int64
#  53  osm_subway_closest_dist              206474 non-null  float64
#  54  osm_train_stop_closest_dist          206474 non-null  float64
#  55  osm_train_stop_points_in_0.005       206474 non-null  int64
#  56  osm_train_stop_points_in_0.0075      206474 non-null  int64
#  57  osm_train_stop_points_in_0.01        206474 non-null  int64
#  58  osm_transport_stop_closest_dist      206474 non-null  float64
#  59  osm_transport_stop_points_in_0.005   206474 non-null  int64
#  60  osm_transport_stop_points_in_0.0075  206474 non-null  int64
#  61  osm_transport_stop_points_in_0.01    206474 non-null  int64
#  62  per_square_meter_price               206474 non-null  float64
#  63  reform_count_of_houses_1000          206474 non-null  int64
#  64  reform_count_of_houses_500           206474 non-null  int64
#  65  reform_house_population_1000         195541 non-null  float64
#  66  reform_house_population_500          186141 non-null  float64
#  67  reform_mean_floor_count_1000         193961 non-null  float64
#  68  reform_mean_floor_count_500          183936 non-null  float64
#  69  reform_mean_year_building_1000       194311 non-null  float64
#  70  reform_mean_year_building_500        184340 non-null  float64
#  71  region                               206474 non-null  object
#  72  total_square                         206474 non-null  float64
#  73  street                               205271 non-null  object
#  74  date                                 206474 non-null  object
#  75  realty_type                          206474 non-null  int64
# dtypes: float64(17), int64(53), object(6)
# memory usage: 119.7+ MB

# %%
df.describe()
# Out:
#               floor            lat            lng  \
# count  76209.000000  206474.000000  206474.000000
# mean       1.856802      54.343090      47.505203
# std        5.416645       4.255719      16.693365
# min       -3.000000      42.651897      19.892178
# 25%        1.000000      53.225391      37.583230
# 50%        1.000000      55.677577      39.676300
# 75%        1.000000      56.296827      55.930234
# max      123.000000      69.492140     151.777000
#
#        osm_amenity_points_in_0.001  osm_amenity_points_in_0.005  \
# count                206474.000000                206474.000000
# mean                      2.686672                    40.283300
# std                       4.180174                    52.692116
# min                       0.000000                     0.000000
# 25%                       0.000000                     7.000000
# 50%                       1.000000                    22.000000
# 75%                       4.000000                    51.000000
# max                      46.000000                   454.000000
#
#        osm_amenity_points_in_0.0075  osm_amenity_points_in_0.01  \
# count                 206474.000000               206474.000000
# mean                      80.950328                  132.200800
# std                      103.803026                  169.929844
# min                        0.000000                    0.000000
# 25%                       16.000000                   28.000000
# 50%                       46.000000                   77.000000
# 75%                      100.000000                  164.000000
# max                      850.000000                 1392.000000
#
#        osm_building_points_in_0.001  osm_building_points_in_0.005  \
# count                 206474.000000                 206474.000000
# mean                       0.038155                      0.891488
# std                        0.397521                      6.963436
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                       27.000000                    586.000000
#
#        osm_building_points_in_0.0075  ...  reform_count_of_houses_1000  \
# count                  206474.000000  ...                206474.000000
# mean                        2.058400  ...                    99.519920
# std                        14.904702  ...                    85.043363
# min                         0.000000  ...                     0.000000
# 25%                         0.000000  ...                    38.000000
# 50%                         0.000000  ...                    85.000000
# 75%                         1.000000  ...                   139.000000
# max                       949.000000  ...                   733.000000
#
#        reform_count_of_houses_500  reform_house_population_1000  \
# count               206474.000000                 195541.000000
# mean                    29.842290                   2031.848114
# std                     27.591946                   1355.356057
# min                      0.000000                      0.000000
# 25%                      9.000000                    917.000000
# 50%                     25.000000                   1946.000000
# 75%                     43.000000                   2970.000000
# max                    289.000000                  18392.000000
#
#        reform_house_population_500  reform_mean_floor_count_1000  \
# count                186141.000000                 193961.000000
# mean                    641.936210                      7.071113
# std                     445.564108                      3.559878
# min                       0.000000                      0.000000
# 25%                     285.000000                      4.592233
# 50%                     599.000000                      6.386792
# 75%                     934.000000                      8.732143
# max                    6105.000000                     53.717949
#
#        reform_mean_floor_count_500  reform_mean_year_building_1000  \
# count                183936.000000                   194311.000000
# mean                      7.383622                     1967.588267
# std                       4.259349                       46.431030
# min                       0.000000                        1.000000
# 25%                       4.625000                     1960.089005
# 50%                       6.418393                     1970.936170
# 75%                       9.133333                     1983.816986
# max                     221.666667                     2019.000000
#
#        reform_mean_year_building_500   total_square    realty_type
# count                  184340.000000  206474.000000  206474.000000
# mean                     1968.017046     509.704513      54.850926
# std                        55.031146    1721.436830      47.864524
# min                         1.000000       5.100000      10.000000
# 25%                      1959.980000      65.000000      10.000000
# 50%                      1971.709677     128.000000      10.000000
# 75%                      1987.000000     336.975000     110.000000
# max                      2020.000000   40000.000000     110.000000
#
# [8 rows x 70 columns]

# %%
df.boxplot('floor', figsize=(15, 10))
plt.show()

# %%
df[(df.floor < 10)].floor.hist()
plt.show()

# %%
pd.options.display.max_rows = 5000
cityFrequency = df.city.value_counts(normalize=True)
print(cityFrequency)
# Out:
# Москва                                                                                             0.203033
# Санкт-Петербург                                                                                    0.067548
# Краснодар                                                                                          0.046994
# Екатеринбург                                                                                       0.030309
# Новосибирск                                                                                        0.023848
# Челябинск                                                                                          0.022395
# Самара                                                                                             0.022206
# Казань                                                                                             0.021577
# Тюмень                                                                                             0.021208
# Уфа                                                                                                0.017959
# Нижний Новгород                                                                                    0.017077
# Ростов-на-Дону                                                                                     0.016632
# Пермь                                                                                              0.013881
# Воронеж                                                                                            0.013241
# Красноярск                                                                                         0.011817
# Саратов                                                                                            0.010762
# Ставрополь                                                                                         0.009866
# Калининград                                                                                        0.009183
# Волгоград                                                                                          0.008790
# Сочи                                                                                               0.008519
# Иркутск                                                                                            0.007851
# Омск                                                                                               0.007643
# Ижевск                                                                                             0.007207
# Барнаул                                                                                            0.007124
# Киров                                                                                              0.006064
# Ярославль                                                                                          0.005705
# Ульяновск                                                                                          0.005647
# Кемерово                                                                                           0.005560
# Тольятти                                                                                           0.005342
# Белгород                                                                                           0.005090
# Новороссийск                                                                                       0.004921
# Пенза                                                                                              0.004901
# Тула                                                                                               0.004867
# Анапа                                                                                              0.004742
# Иваново                                                                                            0.004325
# Липецк                                                                                             0.004277
# Сургут                                                                                             0.004126
# Набережные Челны                                                                                   0.004073
# Балашиха                                                                                           0.003879
# Брянск                                                                                             0.003826
# Новокузнецк                                                                                        0.003574
# Кострома                                                                                           0.003371
# Томск                                                                                              0.003337
# Нижний Тагил                                                                                       0.003274
# Сыктывкар                                                                                          0.003235
# Смоленск                                                                                           0.003177
# Красногорск                                                                                        0.002780
# Вологда                                                                                            0.002751
# Химки                                                                                              0.002722
# Курск                                                                                              0.002693
# Магнитогорск                                                                                       0.002601
# Калуга                                                                                             0.002489
# Волжский                                                                                           0.002373
# Нижневартовск                                                                                      0.002092
# Геленджик                                                                                          0.002087
# Петрозаводск                                                                                       0.002078
# Таганрог                                                                                           0.002068
# Одинцово                                                                                           0.002029
# Королев                                                                                            0.002000
# Энгельс                                                                                            0.001947
# Череповец                                                                                          0.001932
# Саранск                                                                                            0.001903
# Пятигорск                                                                                          0.001874
# Подольск                                                                                           0.001855
# Люберцы                                                                                            0.001724
# Орёл                                                                                               0.001719
# Стерлитамак                                                                                        0.001681
# Мытищи                                                                                             0.001618
# Дзержинск                                                                                          0.001603
# Мурино                                                                                             0.001511
# Электросталь                                                                                       0.001506
# Видное                                                                                             0.001429
# Миасс                                                                                              0.001366
# Ханты-Мансийск                                                                                     0.001259
# Нефтекамск                                                                                         0.001254
# Коммунарка                                                                                         0.001245
# Старый Оскол                                                                                       0.001172
# Кисловодск                                                                                         0.001172
# Волгодонск                                                                                         0.001167
# Сергиев Посад                                                                                      0.001162
# Златоуст                                                                                           0.001158
# Рыбинск                                                                                            0.001148
# Октябрьский                                                                                        0.001148
# Нижнекамск                                                                                         0.001133
# Ангарск                                                                                            0.001114
# Ухта                                                                                               0.001095
# Копейск                                                                                            0.001090
# Михайловск                                                                                         0.001085
# Ессентуки                                                                                          0.001056
# Обнинск                                                                                            0.001032
# Ивантеевка                                                                                         0.001007
# Шахты                                                                                              0.001003
# Альметьевск                                                                                        0.000998
# Орел                                                                                               0.000998
# Бийск                                                                                              0.000988
# Балаково                                                                                           0.000983
# Жуковский                                                                                          0.000959
# Коломна                                                                                            0.000959
# Реутов                                                                                             0.000959
# Каменск-Уральский                                                                                  0.000944
# Батайск                                                                                            0.000940
# Ейск                                                                                               0.000915
# Звенигород                                                                                         0.000877
# Димитровград                                                                                       0.000862
# Новочеркасск                                                                                       0.000857
# Аксай                                                                                              0.000857
# Бердск                                                                                             0.000852
# Раменское                                                                                          0.000838
# Новомосковск                                                                                       0.000833
# Армавир                                                                                            0.000828
# Прокопьевск                                                                                        0.000828
# Невинномысск                                                                                       0.000804
# Березники                                                                                          0.000794
# Туапсе                                                                                             0.000794
# Тобольск                                                                                           0.000794
# Майкоп                                                                                             0.000780
# Братск                                                                                             0.000775
# Серпухов                                                                                           0.000760
# Новокуйбышевск                                                                                     0.000756
# Березовский                                                                                        0.000736
# Воскресенск                                                                                        0.000736
# Кудрово                                                                                            0.000736
# Крымск                                                                                             0.000717
# Котельники                                                                                         0.000707
# Гурьевск                                                                                           0.000702
# Светлогорск                                                                                        0.000683
# Первоуральск                                                                                       0.000664
# Железногорск                                                                                       0.000664
# Сызрань                                                                                            0.000664
# Дмитров                                                                                            0.000664
# Новоалтайск                                                                                        0.000664
# Ногинск                                                                                            0.000659
# Верхняя Пышма                                                                                      0.000654
# Лобня                                                                                              0.000649
# Азов                                                                                               0.000639
# Ачинск                                                                                             0.000630
# Всеволожск                                                                                         0.000625
# Долгопрудный                                                                                       0.000620
# Каменск-Шахтинский                                                                                 0.000620
# Бор                                                                                                0.000615
# Кстово                                                                                             0.000610
# Минеральные Воды                                                                                   0.000610
# Троицк                                                                                             0.000610
# Пушкино                                                                                            0.000596
# Салават                                                                                            0.000596
# Зеленодольск                                                                                       0.000572
# Домодедово                                                                                         0.000572
# Сертолово                                                                                          0.000562
# Щёлково                                                                                            0.000557
# Краснокамск                                                                                        0.000552
# Арзамас                                                                                            0.000542
# Нефтеюганск                                                                                        0.000538
# Белореченск                                                                                        0.000533
# Горячий Ключ                                                                                       0.000523
# Туймазы                                                                                            0.000523
# Кирово-Чепецк                                                                                      0.000518
# Лиски                                                                                              0.000518
# Ленинск-Кузнецкий                                                                                  0.000518
# Солнечногорск                                                                                      0.000513
# Лыткарино                                                                                          0.000513
# Кропоткин                                                                                          0.000513
# Красноармейск                                                                                      0.000509
# Славянск-на-Кубани                                                                                 0.000509
# Гуково                                                                                             0.000504
# Мосрентген                                                                                         0.000494
# Камышин                                                                                            0.000489
# Орехово-Зуево                                                                                      0.000484
# Норильск                                                                                           0.000484
# Тихорецк                                                                                           0.000484
# Чебаркуль                                                                                          0.000484
# Канск                                                                                              0.000484
# Кинешма                                                                                            0.000479
# Ревда                                                                                              0.000479
# Киселевск                                                                                          0.000479
# Усолье-Сибирское                                                                                   0.000475
# Тимашевск                                                                                          0.000460
# Дубна                                                                                              0.000455
# Сарапул                                                                                            0.000455
# Выборг                                                                                             0.000450
# Серов                                                                                              0.000446
# Будённовск                                                                                         0.000436
# Яблоновский                                                                                        0.000426
# Чехов                                                                                              0.000421
# Юрга                                                                                               0.000417
# Щелково                                                                                            0.000407
# Воскресенское                                                                                      0.000402
# Воткинск                                                                                           0.000402
# Кумертау                                                                                           0.000397
# Елабуга                                                                                            0.000397
# Михайловка                                                                                         0.000397
# Заречный                                                                                           0.000392
# Кунгур                                                                                             0.000392
# Клин                                                                                               0.000392
# Минусинск                                                                                          0.000387
# Бугульма                                                                                           0.000387
# Ярцево                                                                                             0.000378
# Белово                                                                                             0.000378
# Сибай                                                                                              0.000378
# Абинск                                                                                             0.000373
# Нягань                                                                                             0.000373
# Московский                                                                                         0.000373
# Мелеуз                                                                                             0.000373
# Гатчина                                                                                            0.000373
# Соликамск                                                                                          0.000368
# Вязьма                                                                                             0.000363
# Рубцовск                                                                                           0.000363
# Фрязино                                                                                            0.000363
# Георгиевск                                                                                         0.000358
# Лесной                                                                                             0.000349
# Елец                                                                                               0.000349
# Находка                                                                                            0.000349
# Чайковский                                                                                         0.000349
# Наро-Фоминск                                                                                       0.000349
# Ступино                                                                                            0.000344
# Лениногорск                                                                                        0.000344
# Глазов                                                                                             0.000344
# Южноуральск                                                                                        0.000339
# Арамиль                                                                                            0.000339
# Шелехов                                                                                            0.000339
# Переславль-Залесский                                                                               0.000339
# Новошахтинск                                                                                       0.000334
# Темрюк                                                                                             0.000334
# Новоуральск                                                                                        0.000334
# Полевской                                                                                          0.000329
# Зеленоградск                                                                                       0.000329
# Чистополь                                                                                          0.000324
# Кинель                                                                                             0.000324
# Асбест                                                                                             0.000324
# Осинники                                                                                           0.000324
# Мегион                                                                                             0.000324
# Пионерский                                                                                         0.000320
# Стрежевой                                                                                          0.000320
# Ишимбай                                                                                            0.000320
# Северск                                                                                            0.000320
# Чусовой                                                                                            0.000320
# Сальск                                                                                             0.000320
# Печора                                                                                             0.000315
# Славгород                                                                                          0.000315
# Луховицы                                                                                           0.000315
# Алексин                                                                                            0.000310
# Малоярославец                                                                                      0.000305
# Дзержинский                                                                                        0.000305
# Балашов                                                                                            0.000305
# Рузаевка                                                                                           0.000300
# Егорьевск                                                                                          0.000300
# Владивосток                                                                                        0.000300
# Ишим                                                                                               0.000300
# Шуя                                                                                                0.000295
# Донской                                                                                            0.000295
# Междуреченск                                                                                       0.000295
# Шатура                                                                                             0.000295
# Ялуторовск                                                                                         0.000295
# Павлово                                                                                            0.000295
# Кудрово г.                                                                                         0.000291
# Истра                                                                                              0.000291
# Кашира                                                                                             0.000291
# Искитим                                                                                            0.000286
# Краснотурьинск                                                                                     0.000286
# Старая Купавна                                                                                     0.000286
# Курганинск                                                                                         0.000281
# Белая Калитва                                                                                      0.000281
# Кузнецк                                                                                            0.000281
# Лабинск                                                                                            0.000281
# Чапаевск                                                                                           0.000276
# Коркино                                                                                            0.000276
# Белебей                                                                                            0.000271
# Сысерть                                                                                            0.000271
# Приморско-Ахтарск                                                                                  0.000271
# Дюртюли                                                                                            0.000266
# Каневская                                                                                          0.000266
# Апрелевка                                                                                          0.000266
# Павловский Посад                                                                                   0.000266
# Железнодорожный                                                                                    0.000266
# Вольск                                                                                             0.000262
# Азнакаево                                                                                          0.000257
# Сосновый Бор                                                                                       0.000257
# Лысьва                                                                                             0.000257
# Можга                                                                                              0.000257
# Маркова                                                                                            0.000252
# Югорск                                                                                             0.000252
# Мыски                                                                                              0.000252
# Усть-Лабинск                                                                                       0.000247
# Советск                                                                                            0.000242
# Гулькевичи                                                                                         0.000242
# Железноводск                                                                                       0.000242
# Ефремов                                                                                            0.000242
# Сафоново                                                                                           0.000242
# Черняховск                                                                                         0.000237
# Среднеуральск                                                                                      0.000237
# Белорецк                                                                                           0.000232
# Слободской                                                                                         0.000232
# Изобильный                                                                                         0.000232
# Советский                                                                                          0.000232
# Ростов                                                                                             0.000232
# Бирск                                                                                              0.000232
# Белоярский                                                                                         0.000232
# Усинск                                                                                             0.000232
# Красногорск городской округ, Нахабино рп                                                           0.000228
# Кыштым                                                                                             0.000228
# Волоколамск                                                                                        0.000228
# Россошь                                                                                            0.000228
# Шебекино                                                                                           0.000223
# Реж                                                                                                0.000223
# Сосновоборск                                                                                       0.000223
# Апшеронск                                                                                          0.000223
# Алексеевка                                                                                         0.000218
# Балахна                                                                                            0.000213
# Щербинка                                                                                           0.000213
# Пыть-Ях                                                                                            0.000213
# Всеволожский район, Заневское городское поселение, пос. Янино-1                                    0.000213
# Мценск                                                                                             0.000213
# Кохма                                                                                              0.000208
# Клинцы                                                                                             0.000208
# Усть-Илимск                                                                                        0.000208
# Павловск                                                                                           0.000208
# Качканар                                                                                           0.000203
# Новый Оскол                                                                                        0.000203
# Ессентукская                                                                                       0.000203
# Кореновск                                                                                          0.000203
# Брюховецкая                                                                                        0.000203
# Шарыпово                                                                                           0.000203
# Городец                                                                                            0.000203
# Новозыбков                                                                                         0.000203
# Высокая Гора                                                                                       0.000199
# Ртищево                                                                                            0.000199
# Новая Усмань                                                                                       0.000199
# Радужный                                                                                           0.000199
# Богородицк                                                                                         0.000199
# Каменка                                                                                            0.000199
# Краснослободск                                                                                     0.000199
# Губкин                                                                                             0.000194
# Миллерово                                                                                          0.000194
# Ростов-на-Дону, Нахичевань                                                                         0.000194
# Анжеро-Судженск                                                                                    0.000194
# Щекино                                                                                             0.000194
# Свердлова                                                                                          0.000194
# Янаул                                                                                              0.000194
# Черемхово                                                                                          0.000194
# Ливны                                                                                              0.000194
# Маркс                                                                                              0.000194
# Голицыно                                                                                           0.000189
# Рославль                                                                                           0.000189
# Краснодар городской округ, пос. Российский                                                         0.000189
# Красногорск городской округ, д. Путилково                                                          0.000189
# Заводоуковск                                                                                       0.000189
# Десногорск                                                                                         0.000184
# Городище                                                                                           0.000184
# Семилуки                                                                                           0.000184
# Узловая                                                                                            0.000184
# Северская                                                                                          0.000179
# Красноуфимск                                                                                       0.000179
# Заринск                                                                                            0.000179
# Красный Сулин                                                                                      0.000179
# Урюпинск                                                                                           0.000179
# Яхрома                                                                                             0.000179
# Кущевская                                                                                          0.000174
# Давлеканово                                                                                        0.000174
# Зеленокумск                                                                                        0.000174
# Петровск                                                                                           0.000174
# Озерск                                                                                             0.000174
# Агрыз                                                                                              0.000174
# Назарово                                                                                           0.000174
# Дегтярск                                                                                           0.000174
# Борисоглебск                                                                                       0.000174
# Лесосибирск                                                                                        0.000170
# Чернушка                                                                                           0.000170
# Топки                                                                                              0.000170
# Великий Устюг                                                                                      0.000170
# Похвистнево                                                                                        0.000165
# Валуйки                                                                                            0.000165
# Янино-1                                                                                            0.000165
# Углич                                                                                              0.000165
# Вятские Поляны                                                                                     0.000165
# Нерехта                                                                                            0.000165
# Ирбит                                                                                              0.000165
# Светлый                                                                                            0.000165
# Комсомольск                                                                                        0.000165
# Вичуга                                                                                             0.000160
# Краснообск                                                                                         0.000160
# Мариинск                                                                                           0.000160
# Люберцы городской округ, пос. Мирный, Томилино Парк ЖК                                             0.000160
# Верхняя Салда                                                                                      0.000160
# Мостовской                                                                                         0.000160
# Кочубеевское                                                                                       0.000160
# Кушва                                                                                              0.000160
# Сухой Лог                                                                                          0.000160
# Тогучин                                                                                            0.000160
# Донецк                                                                                             0.000160
# Учалы                                                                                              0.000155
# Андреевка                                                                                          0.000155
# Куровское                                                                                          0.000155
# Светлоград                                                                                         0.000155
# Жигулевск                                                                                          0.000155
# Богданович                                                                                         0.000155
# Добрянка                                                                                           0.000155
# Дивногорск                                                                                         0.000155
# Острогожск                                                                                         0.000155
# Морозовск                                                                                          0.000155
# Новокубанск                                                                                        0.000155
# Люберцы городской округ, Октябрьский рп                                                            0.000155
# Камень-на-Оби                                                                                      0.000150
# Ипатово                                                                                            0.000150
# Тутаев                                                                                             0.000150
# Коммунар                                                                                           0.000150
# Динская                                                                                            0.000150
# Егорлыкская                                                                                        0.000150
# Омутнинск                                                                                          0.000150
# Озёры                                                                                              0.000150
# Полтавская                                                                                         0.000150
# Кириши                                                                                             0.000150
# Хотьково                                                                                           0.000150
# Выкса                                                                                              0.000150
# Сердобск                                                                                           0.000150
# Павловская                                                                                         0.000145
# Одинцовский городской округ, пос. ВНИИССОК                                                         0.000145
# Нововоронеж                                                                                        0.000145
# Заволжье                                                                                           0.000145
# Усть-Кут                                                                                           0.000145
# Благовещенск                                                                                       0.000145
# Отрадная                                                                                           0.000140
# Невьянск                                                                                           0.000140
# Строитель                                                                                          0.000140
# Заинск                                                                                             0.000140
# Воркута                                                                                            0.000140
# Шарья                                                                                              0.000140
# Алапаевск                                                                                          0.000136
# Алейск                                                                                             0.000136
# Фролово                                                                                            0.000136
# Урай                                                                                               0.000136
# Лангепас                                                                                           0.000136
# Таштагол                                                                                           0.000136
# Тотьма                                                                                             0.000136
# Родники                                                                                            0.000136
# Ленинский городской округ, д. Мисайлово                                                            0.000136
# Балтийск                                                                                           0.000136
# Усмань                                                                                             0.000131
# Черноголовка                                                                                       0.000131
# Нурлат                                                                                             0.000131
# Бавлы                                                                                              0.000131
# Гусев                                                                                              0.000131
# Кингисепп                                                                                          0.000131
# Кулебаки                                                                                           0.000131
# Луга                                                                                               0.000131
# Красноусольский                                                                                    0.000131
# ...
# Артемовский городской округ, пос. Красногвардейский                                                0.000005
# Семеновский городской округ, пос. Богоявление                                                      0.000005
# Вяртсиля                                                                                           0.000005
# Красноярский район, с. Екатериновка                                                                0.000005
# Минераловодский городской округ, пос. Ленинский                                                    0.000005
# Воскресенский район, Фединское с/пос, пос. Сетовка                                                 0.000005
# Бакчар                                                                                             0.000005
# Томский район, пос. Копылово                                                                       0.000005
# Вологодский район, Семенковское с/пос, пос. Кувшиново                                              0.000005
# Всеволожский район, Морозовское городское поселение, Имени Морозова городской поселок              0.000005
# Новосибирский район, Станционный с/с, пос. Садовый                                                 0.000005
# Омский район, с. Розовка                                                                           0.000005
# Красноярский район, Новосемейкино городское поселение, Сокский-1 СНТ                               0.000005
# Темиргоевская                                                                                      0.000005
# Елизаветинское шоссе                                                                               0.000005
# Сюмсинский район, с. Сюмси                                                                         0.000005
# Мошковский район, пос. Октябрьский                                                                 0.000005
# Переславль-Залесский городской округ, д. Соловеново                                                0.000005
# Песчанокопский район, с. Летник                                                                    0.000005
# Озинки                                                                                             0.000005
# Ачинский район, Малиновский с/с, Ветеран садовое общество                                          0.000005
# Белгородский район, пос. Дубовое, Улитка мкр, № 1 кв-л                                             0.000005
# Талицы                                                                                             0.000005
# посёлок Веселовка                                                                                  0.000005
# Иркутский район, с. Пивовариха                                                                     0.000005
# Львовка                                                                                            0.000005
# Чернушинский городской округ, пос. Азинский                                                        0.000005
# Мытищи городской округ, д. Грибки                                                                  0.000005
# Иогач                                                                                              0.000005
# Балахнинский район, Первое Мая рп                                                                  0.000005
# Белоярский городской округ, пос. Прохладный                                                        0.000005
# Копанская                                                                                          0.000005
# посёлок городского типа Борисовка                                                                  0.000005
# Княгининский район, д. Большая Андреевка                                                           0.000005
# Красновка                                                                                          0.000005
# Высокогорский район, с. Пермяки                                                                    0.000005
# Шекснинский район, д. Митицыно                                                                     0.000005
# Ломоносовский район                                                                                0.000005
# Ступино городской округ, с. Семеновское                                                            0.000005
# Белоярский городской округ, с. Колюткино                                                           0.000005
# Мытищи городской округ, с. Федоскино                                                               0.000005
# Песьянка                                                                                           0.000005
# Ступино городской округ, Новое Чирково кп                                                          0.000005
# Зональное                                                                                          0.000005
# Усогорск                                                                                           0.000005
# Варшко                                                                                             0.000005
# Ставропольский район, с. Сосновый Солонец                                                          0.000005
# Демидовский район, Пржевальское пгт                                                                0.000005
# Износковский район, с. Износки                                                                     0.000005
# посёлок городского типа Усть-Кинельский                                                            0.000005
# Хапо-Ое                                                                                            0.000005
# Корткеросский район, с. Маджа                                                                      0.000005
# Злынка                                                                                             0.000005
# рабочий посёлок Бутово                                                                             0.000005
# Дальнеконстантиновский район, д. Криуша                                                            0.000005
# Кудряшовский дп                                                                                    0.000005
# Балтайский район, с. Балтай                                                                        0.000005
# Крутишка                                                                                           0.000005
# Саранск городской округ, с. Горяйновка                                                             0.000005
# Луховицы городской округ, с. Григорьевское                                                         0.000005
# Курганинский район, Петропавловская ст-ца                                                          0.000005
# Орехово-Зуевский городской округ, д. Малая Дубна                                                   0.000005
# Емельяновский район, Палати СНТ                                                                    0.000005
# Кстовский район, д. Подлесово                                                                      0.000005
# Одинцовский городской округ, пос. Сосны                                                            0.000005
# Мошковский район, пос. Радуга                                                                      0.000005
# Ставропольский район                                                                               0.000005
# Туапсинский район, с. Индюк                                                                        0.000005
# Славянка                                                                                           0.000005
# Солонешное                                                                                         0.000005
# Солнечногорск городской округ, д. Лыткино                                                          0.000005
# Спасское                                                                                           0.000005
# рабочий посёлок Хорлово                                                                            0.000005
# Тевриз                                                                                             0.000005
# Новогорск                                                                                          0.000005
# Каменский городской округ, с. Покровское                                                           0.000005
# Петрово                                                                                            0.000005
# Объячево                                                                                           0.000005
# Русский Камешкир                                                                                   0.000005
# Архангельский район, д. Новоустиновка                                                              0.000005
# Слободо-Туринский район, с. Сладковское                                                            0.000005
# Веневский район, пос. Оленьковский                                                                 0.000005
# Талдомский городской округ, Дальнепрудный тер.                                                     0.000005
# Тарусский район, с. Некрасово                                                                      0.000005
# посёлок городского типа Знаменка                                                                   0.000005
# Гаврилов-Ямский район                                                                              0.000005
# Солтон                                                                                             0.000005
# Новоусманский район, пос. Совхоз Масловский 2-е отделение                                          0.000005
# Мокшанский район, пос. Волынский                                                                   0.000005
# Шпаковский район, с. Татарка                                                                       0.000005
# Липецкий район, с. Боринское                                                                       0.000005
# Средняя Елюзань                                                                                    0.000005
# Приозерский район, пос. Мичуринское                                                                0.000005
# Переславль-Залесский городской округ, с. Берендеево                                                0.000005
# Северное                                                                                           0.000005
# Волховский район, д. Бережки                                                                       0.000005
# Непряхино                                                                                          0.000005
# Белореченский район                                                                                0.000005
# Семилукский район, Стрелица рп                                                                     0.000005
# Антиповка                                                                                          0.000005
# Шпаковский район, с. Верхнерусское                                                                 0.000005
# Кривянская                                                                                         0.000005
# посёлок станции Суроватиха                                                                         0.000005
# Красногвардейский район, с. Ливенка                                                                0.000005
# Тюменский район, д. Костылева                                                                      0.000005
# Дмитровский городской округ, д. Мишуково                                                           0.000005
# Ребрихинский район, с. Георгиевка                                                                  0.000005
# Белая Гора                                                                                         0.000005
# Архангельская                                                                                      0.000005
# Кондоль                                                                                            0.000005
# Волжский район, Лопатино с/пос, пос. НПС Дружба                                                    0.000005
# посёлок Куеда                                                                                      0.000005
# Топчихинский район, с. Белояровка                                                                  0.000005
# Краснодар городской округ, Знаменский ДНТ                                                          0.000005
# Ревякино                                                                                           0.000005
# Бураевский район, с. Бураево                                                                       0.000005
# Песковка                                                                                           0.000005
# Чёрмоз                                                                                             0.000005
# Ферма                                                                                              0.000005
# Игринский район, пос. Игра, пос. Нефтеразведчиков                                                  0.000005
# Ленинский городской округ, д. Горки                                                                0.000005
# Кунгурский район, пос. Осиновое озеро                                                              0.000005
# Красногорский район, с. Быстрянка                                                                  0.000005
# Полтавка                                                                                           0.000005
# Верхнеландеховский район, Верхний Ландех пгт                                                       0.000005
# Марксовский район, с. Андреевка                                                                    0.000005
# Ленинградский район, Ленинградская ст-ца                                                           0.000005
# Кузьминские Отвержки                                                                               0.000005
# посёлок городского типа Хотынец                                                                    0.000005
# Юрьянский район, Юрья пгт                                                                          0.000005
# Солнечногорск городской округ, д. Дубинино                                                         0.000005
# Пензенский район                                                                                   0.000005
# Домодедово городской округ, Вельяминово СНТ                                                        0.000005
# улица Пром Площадка СУМЗа                                                                          0.000005
# Мартыновский район, Большая Мартыновка сл.                                                         0.000005
# Большие Ключищи                                                                                    0.000005
# пос. Вохма                                                                                         0.000005
# Дубенский район, пос. Гвардейский                                                                  0.000005
# Томский район, д. Кисловка                                                                         0.000005
# Колышлейский район, Колышлей рп                                                                    0.000005
# Минераловодский городской округ, пос. Змейка                                                       0.000005
# Красногорск городской округ, д. Путилково, Путилково ЖК                                            0.000005
# Урожайное                                                                                          0.000005
# Азнакаевский район, Актюбинский пгт                                                                0.000005
# Балаганск                                                                                          0.000005
# Чебаркульский район, с. Травники                                                                   0.000005
# Пожарский район, с. Светлогорье, Первый мкр                                                        0.000005
# Name: city, dtype: float64

# %%
def isMediumCity(name):
  return cityFrequency[name] >= 0.005 and cityFrequency[name] < 0.015

def isSmallCity(name):
  return cityFrequency[name] >= 0.001 and cityFrequency[name] < 0.005 

def isLittleCity(name):
  return cityFrequency[name] >= 0.001 and cityFrequency[name] < 0.005 

df = df.assign(
  city_moskow=((df.city == "Москва")).astype(int),
  city_saint_petersburg=((df.city == "Санкт-Петербург")).astype(int),
  city_krasnodar=((df.city == "Краснодар")).astype(int),
  city_ekaterinburg=((df.city == "Екатеринбург")).astype(int),
  city_novosibirsk=((df.city == "Новосибирск")).astype(int),
  city_chelyabinsk=((df.city == "Челябинск")).astype(int),
  city_samara=((df.city == "Самара")).astype(int),
  city_kazan=((df.city == "Казань")).astype(int),
  city_tymen=((df.city == "Тюмень")).astype(int),
  city_ufa=((df.city == "Уфа")).astype(int),
  city_nino=((df.city == "Нижний Новгород")).astype(int),
  city_rod=((df.city == "Ростов-на-Дону")).astype(int),
  city_medium=((df.city.apply(isMediumCity))).astype(int),
  city_small=((df.city.apply(isSmallCity))).astype(int),
  city_little=((df.city.apply(isLittleCity))).astype(int)
)

# %%
def amenityDependency(in100m, in500m, in750m, in1000m):
  return in100m ** 1.5 + (in500m - in100m) ** 0.8 + (in750m - in500m) ** 0.6 + (in1000m - in750m) ** 0.4

# %%
df = df.assign(
  amenity=df.apply(lambda row: amenityDependency(row['osm_amenity_points_in_0.001'], 
                                                  row['osm_amenity_points_in_0.005'],
                                                  row['osm_amenity_points_in_0.0075'],
                                                  row['osm_amenity_points_in_0.01']), 
                    axis=1)
)

# %%
df.amenity.hist(bins=50)
plt.show()

# %%
from math import log1p
df = df.assign(
  amenity_ln=df.amenity.apply(log1p)
)

# %%
df.amenity_ln.hist(bins=50)
plt.show()

# %%
def medcouple(x):
  Q2 = x.quantile(q=0.5)
  dist = np.asarray([])
  for i in range(0, len(x)):
    for j in range(0, len(x)):
      if x[i] != x[j] and x[i] <= Q2 and x[j] < Q2:
        np.append(dist, (x[j] - Q2) - (Q2 - x[i])) / (x[j] - x[i])
  return dist.median()

# %%
median = df.amenity_ln.median()
print(median)
df = df.assign(
  amenity_ln_center=df.amenity_ln.apply(lambda x: x - median)
)
# Out:
# 3.231941996852354

# %%
df.amenity_ln_center.hist(bins=50)
plt.show()

# %%
q25, q75 = df.amenity_ln_center.quantile(q=0.25), df.amenity_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)
# Out:
# q25 = -0.6877662961896158
# q75 = 0.5932989661528209

# %%
median = df.amenity_ln_center.median()
df = df.assign(
  amenity_ln_center_norm=df.amenity_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50)
plt.show()

# %%
df.boxplot(['osm_building_points_in_0.001',
            'osm_building_points_in_0.005',
            'osm_building_points_in_0.0075',
            'osm_building_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  osm_building_points_modified_in_0_001=df['osm_building_points_in_0.001'] / 5.0,
  osm_building_points_modified_in_0_005=df['osm_building_points_in_0.005'].apply(log1p),
  osm_building_points_modified_in_0_0075=df['osm_building_points_in_0.0075'].apply(log1p),
  osm_building_points_modified_in_0_01=df['osm_building_points_in_0.01'].apply(log1p),
)

df.boxplot(['osm_building_points_modified_in_0_001',
            'osm_building_points_modified_in_0_005',
            'osm_building_points_modified_in_0_0075',
            'osm_building_points_modified_in_0_01'
])
plt.show()

# %%
def buildingDependency(in100m, in500m, in750m, in1000m):
  return in100m  * 0.4 + (in500m - in100m) ** 0.6 + (in750m - in500m) ** 0.8 + (in1000m - in750m) ** 1.5

# %%
df = df.assign(
  building=df.apply(lambda row: buildingDependency(row['osm_building_points_in_0.001'],
                                                    row['osm_building_points_in_0.005'],
                                                    row['osm_building_points_in_0.0075'],
                                                    row['osm_building_points_in_0.01']), 
                    axis=1)
  )

df.building.hist(bins=50)
plt.show()

df.boxplot('building')
plt.show()

# %%
import math

df = df.assign(
  building_ln=df.building.apply(lambda x: math.log(x + 1, 15000))
)
df.building_ln.hist(bins=50)
plt.show()

df.boxplot('building_ln')
plt.show()

# %% [markdown]
# :(

# %%
df.boxplot(['osm_catering_points_in_0.001',
            'osm_catering_points_in_0.005',
            'osm_catering_points_in_0.0075',
            'osm_catering_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  catering=df.apply(lambda row: amenityDependency(row['osm_catering_points_in_0.001'], 
                                                  row['osm_catering_points_in_0.005'],
                                                  row['osm_catering_points_in_0.0075'],
                                                  row['osm_catering_points_in_0.01']), 
                    axis=1)
)
df.catering.hist(bins=50)
plt.show()

# %%
df = df.assign(
  catering_ln=df.catering.apply(log1p)
)
df.catering_ln.hist(bins=50)
plt.show()

# %%
median = df.catering_ln.median()
print(median)
df = df.assign(
  catering_ln_center=df.catering_ln.apply(lambda x: x - median)
)
df.catering_ln_center.hist(bins=50)
plt.show()
# Out:
# 1.8330117640685921

# %%
q25, q75 = df.catering_ln_center.quantile(q=0.25), df.catering_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.catering_ln_center.median()
df = df.assign(
  catering_ln_center_norm=df.catering_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity')
df.catering_ln_center_norm.hist(bins=50, label='catering')
plt.legend()
plt.show()
# Out:
# q25 = -0.7343994754004826
# q75 = 0.672163743721457

# %%
df.boxplot('osm_city_closest_dist')
plt.show()

# %%
df = df.assign(
  city_closest_dist_ln=df.osm_city_closest_dist.apply(log1p)
)
df.city_closest_dist_ln.hist(bins=50)
plt.show()

# %%
median = df.city_closest_dist_ln.median()
print(median)
df = df.assign(
  city_closest_dist_ln_center=df.city_closest_dist_ln.apply(lambda x: x - median)
)
df.city_closest_dist_ln_center.hist(bins=50)
plt.show()
# Out:
# 1.8566587390605132

# %%
q25, q75 = df.city_closest_dist_ln_center.quantile(q=0.25), df.city_closest_dist_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.city_closest_dist_ln_center.median()
df = df.assign(
  city_closest_dist_ln_center_norm=df.city_closest_dist_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
plt.legend()
plt.show()
# Out:
# q25 = -0.5752045817094054
# q75 = 0.6152837783252896

# %%
nearestCityFrequency = df.osm_city_nearest_name.value_counts(normalize=True)
print(nearestCityFrequency)

def isMediumNearestCity(name):
  return nearestCityFrequency[name] >= 0.005 and nearestCityFrequency[name] <= 0.018

def isSmallNearestCity(name):
  return nearestCityFrequency[name] >= 0.001 and nearestCityFrequency[name] < 0.005 

def isLittleNearestCity(name):
  return nearestCityFrequency[name] >= 0.001 and nearestCityFrequency[name] < 0.005 

df = df.assign(
  nearest_city_moskow=((df.osm_city_nearest_name == "Москва")).astype(int),
  nearest_city_saint_petersburg=((df.osm_city_nearest_name == "Санкт-Петербург")).astype(int),
  nearest_city_krasnodar=((df.osm_city_nearest_name == "Краснодар")).astype(int),
  nearest_city_ekaterinburg=((df.osm_city_nearest_name == "Екатеринбург")).astype(int),
  nearest_city_novosibirsk=((df.osm_city_nearest_name == "Новосибирск")).astype(int),
  nearest_city_chelyabinsk=((df.osm_city_nearest_name == "Челябинск")).astype(int),
  nearest_city_samara=((df.osm_city_nearest_name == "Самара")).astype(int),
  nearest_city_kazan=((df.osm_city_nearest_name == "Казань")).astype(int),
  nearest_city_tymen=((df.osm_city_nearest_name == "Тюмень")).astype(int),
  nearest_city_podolsk=((df.osm_city_nearest_name == "Подольск")).astype(int),
  nearest_city_ufa=((df.osm_city_nearest_name == "Уфа")).astype(int),
  nearest_city_nino=((df.osm_city_nearest_name == "Нижний Новгород")).astype(int),
  nearest_city_rod=((df.osm_city_nearest_name == "Ростов-на-Дону")).astype(int),
  nearest_city_medium=((df.osm_city_nearest_name.apply(isMediumNearestCity))).astype(int),
  nearest_city_small=((df.osm_city_nearest_name.apply(isSmallNearestCity))).astype(int),
  nearest_city_little=((df.osm_city_nearest_name.apply(isLittleNearestCity))).astype(int)
)
# Out:
# Москва               0.133891
# Санкт-Петербург      0.067573
# Краснодар            0.052893
# Екатеринбург         0.033689
# Челябинск            0.025475
# Новосибирск          0.023882
# Самара               0.023722
# Казань               0.023373
# Тюмень               0.023175
# Подольск             0.022332
# Уфа                  0.019663
# Нижний Новгород      0.019436
# Ростов-на-Дону       0.018564
# Пермь                0.017145
# Воронеж              0.016419
# Люберцы              0.016012
# Новороссийск         0.015217
# Красноярск           0.014166
# Химки                0.014026
# Калининград          0.012801
# Ставрополь           0.011793
# Саратов              0.011149
# Одинцово             0.011033
# Долгопрудный         0.010161
# Сочи                 0.009633
# Волгоград            0.009536
# Красногорск          0.009304
# Омск                 0.009042
# Иркутск              0.009033
# Мытищи               0.008921
# Барнаул              0.008703
# Ижевск               0.007875
# Кемерово             0.007163
# Пенза                0.006882
# Белгород             0.006771
# Киров                0.006621
# Ярославль            0.006543
# Ульяновск            0.006257
# Иваново              0.006151
# Брянск               0.005885
# Тула                 0.005841
# Тольятти             0.005720
# Смоленск             0.005197
# Липецк               0.004921
# Зеленоград           0.004901
# Колпино              0.004858
# Новокузнецк          0.004829
# Сыктывкар            0.004809
# Нижний Тагил         0.004722
# Набережные Челны     0.004557
# Пятигорск            0.004524
# Кострома             0.004480
# Сургут               0.004296
# Балашиха             0.004146
# Томск                0.004141
# Королёв              0.004097
# Пушкин               0.003908
# Альметьевск          0.003846
# Домодедово           0.003734
# Таганрог             0.003647
# Орёл                 0.003628
# Магнитогорск         0.003400
# Калуга               0.003269
# Армавир              0.003250
# Курск                0.003245
# Майкоп               0.003235
# Нижневартовск        0.003177
# Бердск               0.003172
# Вологда              0.003129
# Дзержинск            0.003124
# Обнинск              0.003124
# Саранск              0.003075
# Петрозаводск         0.003075
# Волжский             0.002945
# Шахты                0.002736
# Энгельс              0.002678
# Каменск-Уральский    0.002630
# Волгодонск           0.002610
# Сергиев Посад        0.002606
# Старый Оскол         0.002581
# Миасс                0.002562
# Череповец            0.002494
# Нижнекамск           0.002475
# Стерлитамак          0.002349
# Нефтекамск           0.002330
# Щёлково              0.002238
# Первоуральск         0.002213
# Серпухов             0.002209
# Прокопьевск          0.002116
# Коломна              0.002044
# Ангарск              0.001962
# Электросталь         0.001952
# Батайск              0.001899
# Братск               0.001899
# Салават              0.001884
# Рубцовск             0.001874
# Балаково             0.001826
# Ханты-Мансийск       0.001802
# Златоуст             0.001773
# Серов                0.001593
# Жуковский            0.001584
# Тобольск             0.001545
# Пушкино              0.001545
# Березники            0.001535
# Бийск                0.001453
# Ессентуки            0.001429
# Новомосковск         0.001414
# Новочеркасск         0.001400
# Рыбинск              0.001346
# Новошахтинск         0.001322
# Новокуйбышевск       0.001317
# Тамбов               0.001274
# Ачинск               0.001264
# Орехово-Зуево        0.001230
# Раменское            0.001216
# Воскресенск          0.001211
# Кисловодск           0.001191
# Арзамас              0.001191
# Невинномысск         0.001182
# Димитровград         0.001158
# Сызрань              0.001124
# Воткинск             0.001080
# Кирово-Чепецк        0.001017
# Камышин              0.000998
# Ногинск              0.000964
# Елец                 0.000949
# Нефтеюганск          0.000940
# Глазов               0.000693
# Северск              0.000688
# Абакан               0.000634
# Нарьян-Мар           0.000610
# Норильск             0.000581
# Узловая              0.000581
# Тверь                0.000567
# Сарапул              0.000494
# Белорецк             0.000475
# Находка              0.000460
# Соликамск            0.000446
# Муром                0.000407
# Владивосток          0.000320
# Йошкар-Ола           0.000291
# Керчь                0.000286
# Уссурийск            0.000271
# Воркута              0.000242
# Назрань              0.000232
# Салехард             0.000223
# Великий Новгород     0.000223
# Псков                0.000208
# Владимир             0.000194
# Элиста               0.000189
# 饶河县                  0.000170
# Горно-Алтайск        0.000160
# Рязань               0.000150
# Чебоксары            0.000131
# Нальчик              0.000126
# Ковров               0.000121
# Ноябрьск             0.000121
# Артём                0.000107
# Грозный              0.000087
# Черкесск             0.000082
# Орск                 0.000058
# Улан-Удэ             0.000053
# 绥芬河市                 0.000039
# Мурманск             0.000039
# Великие Луки         0.000029
# Чита                 0.000019
# Курган               0.000019
# Магадан              0.000015
# Новый Уренгой        0.000010
# Новочебоксарск       0.000005
# Name: osm_city_nearest_name, dtype: float64

# %%
# mean, std = df.osm_city_nearest_population.apply(log1p).mean(), df.osm_city_nearest_population.apply(log1p).std()
# print(mean, std)
# df.osm_city_nearest_population.apply(lambda x: ((x + mean) / std)).hist(bins=50)
# plt.show()

# %%
df.boxplot(['osm_crossing_points_in_0.001',
            'osm_crossing_points_in_0.005',
            'osm_crossing_points_in_0.0075',
            'osm_crossing_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  crossing=df.apply(lambda row: amenityDependency(row['osm_crossing_points_in_0.001'], 
                                                    row['osm_crossing_points_in_0.005'],
                                                    row['osm_crossing_points_in_0.0075'],
                                                    row['osm_crossing_points_in_0.01']), 
                    axis=1)
)
df.crossing.hist(bins=50)
plt.show()

# %%
df = df.assign(
  crossing_ln=df.crossing.apply(log1p)
)
df.crossing_ln.hist(bins=50)
plt.show()

median = df.crossing_ln.median()
print(median)
df = df.assign(
  crossing_ln_center=df.crossing_ln.apply(lambda x: x - median)
)
df.crossing_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.crossing_ln_center.quantile(q=0.25), df.crossing_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.crossing_ln_center.median()
df = df.assign(
  crossing_ln_center_norm=df.crossing_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
df.crossing_ln_center_norm.hist(bins=50, label='crossing', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 2.6611808973686095
# q25 = -0.6838685172746113
# q75 = 0.46787689173831526

# %% [markdown]
# culture_points kinda :(

# %%
df.boxplot(['osm_finance_points_in_0.001',
            'osm_finance_points_in_0.005',
            'osm_finance_points_in_0.0075',
            'osm_finance_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  finance=df.apply(lambda row: amenityDependency(row['osm_finance_points_in_0.001'], 
                                                  row['osm_finance_points_in_0.005'],
                                                  row['osm_finance_points_in_0.0075'],
                                                  row['osm_finance_points_in_0.01']), 
                    axis=1)
)
df.finance.hist(bins=50)
plt.show()

# %% [markdown]
# finance_points :(

# %%
df.boxplot(['osm_healthcare_points_in_0.005',
            'osm_healthcare_points_in_0.0075',
            'osm_healthcare_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  healthcare=df.apply(lambda row: amenityDependency(row['osm_healthcare_points_in_0.005'],
                                                    row['osm_healthcare_points_in_0.0075'],
                                                    row['osm_healthcare_points_in_0.01'], 
                                                    row['osm_healthcare_points_in_0.01']), 
                    axis=1)
)
df.healthcare.hist(bins=50)
plt.show()

# %% [markdown]
# healthcare :(

# %% [markdown]
# historic :(

# %% [markdown]
# hotels :(

# %%
# osm_leisure_points
df.boxplot(['osm_leisure_points_in_0.005',
            'osm_leisure_points_in_0.0075',
            'osm_leisure_points_in_0.01'
])
plt.show()

# %%
def leisureDependency(in500m, in750m, in1000m):
  return in500m 

df = df.assign(
  leisure=df.apply(lambda row: leisureDependency(row['osm_leisure_points_in_0.005'],
                                                  row['osm_leisure_points_in_0.0075'],
                                                  row['osm_leisure_points_in_0.01']), 
                    axis=1)
)
df.leisure.hist(bins=50)
plt.show()

# %%
df = df.assign(
  leisure_ln=df.leisure.apply(log1p)
)
df.leisure_ln.hist(bins=50)
plt.show()

median = df.leisure_ln.median()
print(median)
df = df.assign(
  leisure_ln_center=df.leisure_ln.apply(lambda x: x - median)
)
df.leisure_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.leisure_ln_center.quantile(q=0.25), df.leisure_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.leisure_ln_center.median()
df = df.assign(
  leisure_ln_center_norm=df.leisure_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
df.crossing_ln_center_norm.hist(bins=50, label='crossing', alpha=0.5)
# df.shops_ln_center_norm.hist(bins=50, label='shops', alpha=0.5)
df.leisure_ln_center_norm.hist(bins=50, label='leisure', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 0.6931471805599453
# q25 = -0.6931471805599453
# q75 = 0.6931471805599453

# %% [markdown]
# leisure :(

# %% [markdown]
# offices :(

# %%
df.boxplot(['osm_shops_points_in_0.001',
            'osm_shops_points_in_0.005',
            'osm_shops_points_in_0.0075',
            'osm_shops_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  shops=df.apply(lambda row: amenityDependency(row['osm_shops_points_in_0.001'], 
                                                row['osm_shops_points_in_0.005'],
                                                row['osm_shops_points_in_0.0075'],
                                                row['osm_shops_points_in_0.01']), 
                    axis=1)
)
df.shops.hist(bins=50)
plt.show()

# %%
df = df.assign(
  shops_ln=df.shops.apply(log1p)
)
df.shops_ln.hist(bins=50)
plt.show()

median = df.shops_ln.median()
print(median)
df = df.assign(
  shops_ln_center=df.shops_ln.apply(lambda x: x - median)
)
df.shops_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.shops_ln_center.quantile(q=0.25), df.shops_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.shops_ln_center.median()
df = df.assign(
  shops_ln_center_norm=df.shops_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
df.crossing_ln_center_norm.hist(bins=50, label='crossing', alpha=0.5)
df.shops_ln_center_norm.hist(bins=50, label='shops', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 2.870286312992593
# q25 = -0.6878932157342572
# q75 = 0.5515500353529719

# %%
df.boxplot('osm_subway_closest_dist')
plt.show()

# %%
df[df.osm_subway_closest_dist < 500].osm_subway_closest_dist.hist()
plt.show()

# %%
df = df.assign(
  subway_in_100m=((df.osm_subway_closest_dist <= 100)).astype(int),
  subway_in_500m=((100 < df.osm_subway_closest_dist) & (df.osm_subway_closest_dist <= 500)).astype(int),
  subway_in_1500m=((500 < df.osm_subway_closest_dist) & (df.osm_subway_closest_dist <= 1500)).astype(int),
  subway_far_away=((1500 < df.osm_subway_closest_dist)).astype(int),
)

# %%
df.boxplot('osm_train_stop_closest_dist')
plt.show()

# %%
df[df.osm_train_stop_closest_dist < 50].osm_train_stop_closest_dist.hist(bins=50)
plt.show()
print(df[df.osm_train_stop_closest_dist < 50].osm_train_stop_closest_dist.quantile(q=0.75))
# Out:
# 5.132028462525832

# %%
df = df.assign(
  train_stop_in_1_5=((df.osm_train_stop_closest_dist <= 1.5)).astype(int),
  train_stop_in_2_55=((1.5 < df.osm_train_stop_closest_dist) & (df.osm_train_stop_closest_dist <= 2.55)).astype(int),
  train_stop_in_5_2=((2.55 < df.osm_train_stop_closest_dist) & (df.osm_train_stop_closest_dist <= 5_2)).astype(int),
  train_stop_far_away=((5.2 < df.osm_train_stop_closest_dist)).astype(int)
)

# %% [markdown]
# train_stop_points skip

# %%
df.boxplot(['osm_transport_stop_points_in_0.005',
            'osm_transport_stop_points_in_0.0075',
            'osm_transport_stop_points_in_0.01'
])
plt.show()

# %%
df = df.assign(
  transport_stop=df.apply(lambda row: amenityDependency(row['osm_transport_stop_points_in_0.005'],
                                                        row['osm_transport_stop_points_in_0.0075'],
                                                        row['osm_transport_stop_points_in_0.01'],
                                                        row['osm_transport_stop_points_in_0.01']), 
                    axis=1)
)
df.transport_stop.hist(bins=50)
plt.show()

# %%
df = df.assign(
  transport_stop_ln=df.transport_stop.apply(log1p)
)
df.transport_stop_ln.hist(bins=50)
plt.show()

median = df.transport_stop_ln.median()
print(median)
df = df.assign(
  transport_stop_ln_center=df.transport_stop_ln.apply(lambda x: x - median)
)
df.transport_stop_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.transport_stop_ln_center.quantile(q=0.25), df.transport_stop_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.transport_stop_ln_center.median()
df = df.assign(
  transport_stop_ln_center_norm=df.transport_stop_ln_center.apply(lambda x: (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.city_closest_dist_ln_center_norm.hist(bins=50, label='city closest dist', alpha=0.5)
df.crossing_ln_center_norm.hist(bins=50, label='crossing', alpha=0.5)
df.shops_ln_center_norm.hist(bins=50, label='shops', alpha=0.5)
df.transport_stop_ln_center_norm.hist(bins=50, label='transport stop', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 2.9870459228339645
# q25 = -0.7714568038634035
# q75 = 0.6647563814341453

# %%
df = df.assign(
  reform_count_of_houses=df.apply(lambda row: row.reform_count_of_houses_500 * 0.4 + (row.reform_count_of_houses_1000 -
                                                                                      row.reform_count_of_houses_500) ** 0.8, axis=1)
)
df.reform_count_of_houses.hist(bins=50)
plt.show()

# %%
df = df.assign(
  reform_count_of_houses_ln=df.reform_count_of_houses.apply(log1p)
)
df.reform_count_of_houses_ln.hist(bins=50)
plt.show()

median = df.reform_count_of_houses_ln.median()
print(median)
df = df.assign(
  reform_count_of_houses_ln_center=df.reform_count_of_houses_ln.apply(lambda x: x - median)
)
df.reform_count_of_houses_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.reform_count_of_houses_ln_center.quantile(q=0.25), df.reform_count_of_houses_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.reform_count_of_houses_ln_center.median()
df = df.assign(
  reform_count_of_houses_ln_center_norm=df.reform_count_of_houses_ln_center.apply(lambda x:  (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.reform_count_of_houses_ln_center_norm.hist(bins=50, label='count of houses', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 3.617253554026773
# q25 = -0.653499661043178
# q75 = 0.4210299727160849

# %%
df = df.assign(
  reform_house_population=df.apply(lambda row: row.reform_house_population_500 * 0.4 + (row.reform_house_population_1000 -
                                                                                        row.reform_house_population_500) ** 0.8, axis=1)
)
df.reform_house_population.hist(bins=50)
plt.show()

# %%
df = df.assign(
  reform_house_population_ln=df.reform_house_population.apply(log1p)
)
df.reform_house_population_ln.hist(bins=50)
plt.show()

median = df.reform_house_population_ln.median()
print(median)
df = df.assign(
  reform_house_population_ln_center=df.reform_house_population_ln.apply(lambda x: x - median)
)
df.reform_house_population_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.reform_house_population_ln_center.quantile(q=0.25), df.reform_house_population_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.reform_house_population_ln_center.median()
df = df.assign(
  reform_house_population_ln_center_norm=df.reform_house_population_ln_center.apply(lambda x:  (x - median) / (q75 - q25))
)
df.fillna(method='ffill', inplace=True)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.reform_house_population_ln_center_norm.hist(bins=50, label='reform house population', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 6.357740734473818
# q25 = -0.5595884420313393
# q75 = 0.35132741347371166

# %% [markdown]
# reform_mean_floor_count ??

# %%
df.boxplot('reform_mean_year_building_1000')
plt.show()

# %%
df[df.reform_mean_year_building_1000 > 1900].reform_mean_year_building_1000.hist(bins=50)
plt.show()

# %%
df = df.assign(
  reform_mean_year_building_1000_before_1600=((df.reform_mean_year_building_1000 <= 1600)).astype(int),
  reform_mean_year_building_1000_before_1900=((1600 < df.reform_mean_year_building_1000) & (df.reform_mean_year_building_1000 <= 1900)).astype(int),
  reform_mean_year_building_1000_last_century=0
)
reform_mean_year_building_1000_last_century=df[df.reform_mean_year_building_1000 > 1900].reform_mean_year_building_1000 - 1900

median = reform_mean_year_building_1000_last_century.median()
print(median)
df = df.assign(
  reform_mean_year_building_1000_last_century_center=reform_mean_year_building_1000_last_century.apply(lambda x: x - median)
)
df.reform_mean_year_building_1000_last_century_center.hist(bins=50)
plt.show()

q25, q75 = df.reform_mean_year_building_1000_last_century_center.quantile(q=0.25), df.reform_mean_year_building_1000_last_century_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.reform_mean_year_building_1000_last_century_center.median()
df = df.assign(
  reform_mean_year_building_1000_last_century_center_norm=df.reform_mean_year_building_1000_last_century_center.apply(lambda x:  (x - median) / (q75 - q25))
)

df.fillna(method='ffill', inplace=True)

df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.reform_mean_year_building_1000_last_century_center_norm.hist(bins=50, label='mean yesr building 1000 last century', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 71.43561319322123
# q25 = -10.12311319322123
# q75 = 12.844386806778743

# %% [markdown]
# region -- nevermind

# %%
df.boxplot('total_square')
plt.show()

# %%
df.total_square.apply(log1p).hist(bins=50)
plt.show()

# %%
df = df.assign(
  total_square_ln=df.total_square.apply(log1p)
)
df.total_square_ln.hist(bins=50)
plt.show()

median = df.total_square_ln.median()
print(median)
df = df.assign(
  total_square_ln_center=df.total_square_ln.apply(lambda x: x - median)
)
df.total_square_ln_center.hist(bins=50)
plt.show()

q25, q75 = df.total_square_ln_center.quantile(q=0.25), df.total_square_ln_center.quantile(q=0.75)
print("q25 =", q25, "\nq75 =", q75)

median = df.total_square_ln_center.median()
df = df.assign(
  total_square_ln_center_norm=df.total_square_ln_center.apply(lambda x:  (x - median) / (q75 - q25))
)
df.amenity_ln_center_norm.hist(bins=50, label='amenity', alpha=0.5)
df.catering_ln_center_norm.hist(bins=50, label='catering', alpha=0.5)
df.total_square_ln_center_norm.hist(bins=50, label='total square', alpha=0.5)
plt.legend()
plt.show()
# Out:
# 4.859812404361672
# q25 = -0.6701576623352468
# q75 = 0.9631595156806532

# %% [markdown]
# street skip

# %%
df = df.assign(
  yyyyMM=df.date.apply(lambda date: str(date)[0:7])
)

df.yyyyMM.head(5)
# Out:
# 0    2020-02
# 1    2020-05
# 2    2020-06
# 3    2020-07
# 4    2020-03
# Name: yyyyMM, dtype: object

# %%
df.to_csv('processed_data/00-features.csv', index=False)
